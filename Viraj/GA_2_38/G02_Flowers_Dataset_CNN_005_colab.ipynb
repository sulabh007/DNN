# %%
0#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Out:
# 0

# %% [markdown]
# # Deep Neural Networks
#
# ## Convolutional Neural Network
# ### Flower Dataset

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from collections.abc import Callable
from typing import Literal
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %matplotlib inline

# %%
gpus = tf.config.list_physical_devices('GPU')

try:
    for g in gpus:
        tf.config.experimental.set_memory_growth(g, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print (len(gpus), 'Phusical GPUs', len(logical_gpus), 'Logical GPUs')
except:
    print ('invalid device')
# Out:
# 1 Phusical GPUs 1 Logical GPUs

# %%
###----------------
### Some parameters
###----------------

inpDir = '/home/dai/Documents/DNN/7.DNN/input'
outDir = '../output'
modelDir = '../models'
subDir = 'flower_photos'
altName = 'cnn_base'

RANDOM_STATE = 24 # REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results


EPOCHS = 150 # number of epochs
ALPHA = 0.001 # learning rate
TEST_SIZE = 0.2
BATCH_SIZE = 32
LR_PATIENCE = 10
FACTOR_LR = 0.5
PATIENCE = 10
IMG_HEIGHT = 190
IMG_WIDTH = 190

# parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

CMAP = 'coolwarm' # plt.cm.Spectral

plt.rcParams.update(params)

# %%
def fn_plot_label(tr_ds , ts_ds):

    plt.figure(figsize=(15,5)) # instantiate the figure

    plt.subplot(1, 2, 1) # first out of 2

    train_labels = tf.concat([lbl for img, lbl in tr_ds], axis= 0).numpy() # get the lables

    unique, _, counts = tf.unique_with_counts(train_labels) # get counts

    plt.bar(range(len(unique)), counts, align='center', color= 'DarkBlue') # barplot the count

    plt.xticks(range(len(unique)), class_names)

    plt.title('Traning Set')

    plt.subplot(1, 2, 2)

    test_labels = tf.concat([lbl for img, lbl in ts_ds], axis= 0).numpy()

    unique, _, counts = tf.unique_with_counts(test_labels)

    plt.bar(range(len(unique)), counts, align='center', color= 'Orange')

    plt.xticks(range(len(unique)), class_names)

    plt.title('Test Set')

# %% [markdown]
# ### Using Flowers Data

# %% [markdown]
# Coverting to Datasets from a directory

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

data_dir = tf.keras.utils.get_file(origin=dataset_url,
                                  fname='flower_photos',
                                  untar=True)

data_dir = pathlib.Path(data_dir)

# %%
data_dir
# Out:
# PosixPath('/root/.keras/datasets/flower_photos')

# %%
os.listdir(data_dir)
# Out:
# ['roses', 'dandelion', 'tulips', 'daisy', 'LICENSE.txt', 'sunflowers']

# %%
#create traning data
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, #path to the data directory
    validation_split = TEST_SIZE, #what ratio of validation data
    subset = 'training', #purpose
    seed = RANDOM_STATE,
    image_size = [IMG_HEIGHT, IMG_WIDTH],
    batch_size = BATCH_SIZE
)

#create test data
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, #path to the data directory
    validation_split = TEST_SIZE, #what ratio of validation data
    subset = 'validation', #purpose
    seed = RANDOM_STATE,
    image_size = [IMG_HEIGHT, IMG_WIDTH],
    batch_size = BATCH_SIZE
)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
# is it picking class names
class_names = train_ds.class_names
class_names
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
plt.figure(figsize=(15,6))

for images, labels in train_ds.take(1): # get me one batch

    for i in range (BATCH_SIZE): #loop over batch

        plt.subplot(int(BATCH_SIZE/8),8, i+1) # access the axis

        plt.grid(False)

        plt.imshow(images[i].numpy().astype('uint8')) # show image convert to numpy and int

        plt.title(class_names[labels[i]])

        plt.axis('off')

    plt.show()

# %%
plt.figure(figsize=(15,6))

for images, labels in test_ds.take(1): # get me one batch

    for i in range (BATCH_SIZE): #loop over batch

        plt.subplot(int(BATCH_SIZE/8),8, i+1) # access the axis

        plt.grid(False)

        plt.imshow(images[i].numpy().astype('uint8')) # show image convert to numpy and int

        plt.title(class_names[labels[i]])

        plt.axis('off')

    plt.show()

# %%
fn_plot_label(train_ds, test_ds)

# %%
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

# %% [markdown]
# ## Random Zoom

# %%
layer = tf.keras.layers.RandomZoom(height_factor=(-0.2, -0.2),
                                   width_factor=(-0.2, -0.2))

plt.figure()

img_num = 3

for images, labels in test_ds.take(1): # get me one batch

    out_images = layer(images)

    plt.subplot(1, 2, 1)
    plt.title('Orignal')
    plt.imshow(images[img_num].numpy().astype('uint8'))

    plt.subplot(1, 2, 2)
    plt.title('Zoomed')
    plt.imshow(out_images[img_num].numpy().astype('uint8'))

# %%
layer = tf.keras.layers.RandomRotation((-0.2, 0.3))

plt.figure()

img_num = 3

for images, labels in test_ds.take(1): # get me one batch

    out_images = layer(images)

    plt.subplot(1, 2, 1)
    plt.title('Orignal')
    plt.imshow(images[img_num].numpy().astype('uint8'))

    plt.subplot(1, 2, 2)
    plt.title('Rotated')
    plt.imshow(out_images[img_num].numpy().astype('uint8'))

# %%
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

test_ds = test_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Build model
dor1 = 0.01
knl_reg = tf.keras.regularizers.L2(l2 = 0.001)
model = tf.keras.Sequential()

model.add(tf.keras.layers.RandomRotation((-0.2, 0.3)))

model.add(tf.keras.layers.Rescaling(1/255.)), # Convert between 0 and 1

###-------
### Set 1
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(8, (3,3),kernel_regularizer = knl_reg)), # 188 x 188 x 8

model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu'))

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 94 x 94 x 8

###-------
### Set 2
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(16, (3,3),kernel_regularizer = knl_reg)), # 92 x 92 x 16

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu'))

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 46 x 46 x 16

###-------
### Set 3
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(32, (3,3),kernel_regularizer = knl_reg)), # 44 x 44 x 32

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu'))

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 22 x 22 x 32

###-------
### Set 4
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(64, (3,3),kernel_regularizer = knl_reg)), # 20 x 20 x 64

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu'))

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 10 x 10 x 64

###-------
### Set 5
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(128, (3,3),kernel_regularizer = knl_reg)), # 8 x 8 x 128

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu'))

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 4 x 4 x 128

###-------
### Set 6
###-------

model.add(tf.keras.layers.Conv2D(256, (3,3),kernel_regularizer = knl_reg)), # 2 x 2 x 256

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu'))

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
###------------
### Head Start
###------------
model.add(tf.keras.layers.Flatten()), # Flatten

model.add(tf.keras.layers.Dense(256,kernel_regularizer = knl_reg)), # Dense 1

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu'))

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))

model.add(tf.keras.layers.Dense(5)) #Output

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE,
    mode = 'auto',
    baseline = None,
    verbose=1,
    restore_best_weights=True,
    start_from_epoch=0,
)
lr_decay = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=FACTOR_LR,
    patience=LR_PATIENCE,
    verbose=1,
    mode='auto',

)

#define model file path
modelFile = os.path.join(modelDir, subDir, altName)

#define checkpoint callback
model_callback = tf.keras.callbacks.ModelCheckpoint(
    modelFile,
    monitor = 'val_loss',
    verbose = 1,
    save_best_only = True,
    save_weights_only = True,
    mode = 'auto'
)

# %%
optim = tf.keras.optimizers.Adam(learning_rate = ALPHA)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

model.compile(optimizer = optim, loss = loss_fn, metrics = ['accuracy'])

# %%
history = model.fit(train_ds, validation_data=test_ds,
                    epochs=EPOCHS, verbose = 1,
                    batch_size=BATCH_SIZE,
                    callbacks=[early_stopping, lr_decay, model_callback])
# Out:
# Epoch 1/150
# 92/92 [==============================] - ETA: 0s - loss: 1.7617 - accuracy: 0.3937
# Epoch 1: val_loss improved from inf to 1.76022, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 73ms/step - loss: 1.7617 - accuracy: 0.3937 - val_loss: 1.7602 - val_accuracy: 0.3025 - lr: 0.0010
# Epoch 2/150
# 91/92 [============================>.] - ETA: 0s - loss: 1.3366 - accuracy: 0.5223
# Epoch 2: val_loss did not improve from 1.76022
# 92/92 [==============================] - 2s 21ms/step - loss: 1.3357 - accuracy: 0.5232 - val_loss: 1.8941 - val_accuracy: 0.2943 - lr: 0.0010
# Epoch 3/150
# 90/92 [============================>.] - ETA: 0s - loss: 1.1980 - accuracy: 0.5875
# Epoch 3: val_loss did not improve from 1.76022
# 92/92 [==============================] - 2s 24ms/step - loss: 1.1961 - accuracy: 0.5889 - val_loss: 1.7640 - val_accuracy: 0.3801 - lr: 0.0010
# Epoch 4/150
# 91/92 [============================>.] - ETA: 0s - loss: 1.0874 - accuracy: 0.6308
# Epoch 4: val_loss improved from 1.76022 to 1.48519, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 2s 24ms/step - loss: 1.0859 - accuracy: 0.6318 - val_loss: 1.4852 - val_accuracy: 0.4714 - lr: 0.0010
# Epoch 5/150
# 91/92 [============================>.] - ETA: 0s - loss: 1.0261 - accuracy: 0.6442
# Epoch 5: val_loss improved from 1.48519 to 1.18964, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 2s 22ms/step - loss: 1.0248 - accuracy: 0.6448 - val_loss: 1.1896 - val_accuracy: 0.6144 - lr: 0.0010
# Epoch 6/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.9985 - accuracy: 0.6542
# Epoch 6: val_loss did not improve from 1.18964
# 92/92 [==============================] - 2s 22ms/step - loss: 0.9962 - accuracy: 0.6543 - val_loss: 1.4627 - val_accuracy: 0.5409 - lr: 0.0010
# Epoch 7/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.9619 - accuracy: 0.6700
# Epoch 7: val_loss improved from 1.18964 to 1.17208, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 2s 22ms/step - loss: 0.9606 - accuracy: 0.6700 - val_loss: 1.1721 - val_accuracy: 0.6117 - lr: 0.0010
# Epoch 8/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.9292 - accuracy: 0.6786
# Epoch 8: val_loss did not improve from 1.17208
# 92/92 [==============================] - 2s 21ms/step - loss: 0.9273 - accuracy: 0.6788 - val_loss: 1.3432 - val_accuracy: 0.5477 - lr: 0.0010
# Epoch 9/150
# 90/92 [============================>.] - ETA: 0s - loss: 0.9199 - accuracy: 0.6819
# Epoch 9: val_loss did not improve from 1.17208
# 92/92 [==============================] - 2s 24ms/step - loss: 0.9148 - accuracy: 0.6849 - val_loss: 1.5030 - val_accuracy: 0.5599 - lr: 0.0010
# Epoch 10/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.8983 - accuracy: 0.6892
# Epoch 10: val_loss improved from 1.17208 to 1.11279, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 2s 23ms/step - loss: 0.8970 - accuracy: 0.6901 - val_loss: 1.1128 - val_accuracy: 0.6213 - lr: 0.0010
# Epoch 11/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.8742 - accuracy: 0.6992
# Epoch 11: val_loss did not improve from 1.11279
# 92/92 [==============================] - 2s 21ms/step - loss: 0.8722 - accuracy: 0.7003 - val_loss: 1.1686 - val_accuracy: 0.6240 - lr: 0.0010
# Epoch 12/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.8585 - accuracy: 0.7067
# Epoch 12: val_loss did not improve from 1.11279
# 92/92 [==============================] - 2s 21ms/step - loss: 0.8563 - accuracy: 0.7074 - val_loss: 1.2503 - val_accuracy: 0.5926 - lr: 0.0010
# Epoch 13/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.8469 - accuracy: 0.7091
# Epoch 13: val_loss improved from 1.11279 to 1.09860, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 2s 22ms/step - loss: 0.8451 - accuracy: 0.7098 - val_loss: 1.0986 - val_accuracy: 0.6322 - lr: 0.0010
# Epoch 14/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.8440 - accuracy: 0.7078
# Epoch 14: val_loss did not improve from 1.09860
# 92/92 [==============================] - 2s 21ms/step - loss: 0.8417 - accuracy: 0.7084 - val_loss: 1.1964 - val_accuracy: 0.6158 - lr: 0.0010
# Epoch 15/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.8247 - accuracy: 0.7184
# Epoch 15: val_loss did not improve from 1.09860
# 92/92 [==============================] - 2s 23ms/step - loss: 0.8228 - accuracy: 0.7197 - val_loss: 1.2332 - val_accuracy: 0.6090 - lr: 0.0010
# Epoch 16/150
# 90/92 [============================>.] - ETA: 0s - loss: 0.8206 - accuracy: 0.7170
# Epoch 16: val_loss did not improve from 1.09860
# 92/92 [==============================] - 2s 24ms/step - loss: 0.8161 - accuracy: 0.7190 - val_loss: 1.1079 - val_accuracy: 0.6240 - lr: 0.0010
# Epoch 17/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.7982 - accuracy: 0.7277
# Epoch 17: val_loss did not improve from 1.09860
# 92/92 [==============================] - 2s 22ms/step - loss: 0.7962 - accuracy: 0.7285 - val_loss: 1.1526 - val_accuracy: 0.6144 - lr: 0.0010
# Epoch 18/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.7963 - accuracy: 0.7387
# Epoch 18: val_loss improved from 1.09860 to 1.09621, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 2s 23ms/step - loss: 0.7942 - accuracy: 0.7388 - val_loss: 1.0962 - val_accuracy: 0.6199 - lr: 0.0010
# Epoch 19/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.7769 - accuracy: 0.7294
# Epoch 19: val_loss improved from 1.09621 to 0.98318, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 2s 23ms/step - loss: 0.7751 - accuracy: 0.7299 - val_loss: 0.9832 - val_accuracy: 0.6839 - lr: 0.0010
# Epoch 20/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.7624 - accuracy: 0.7448
# Epoch 20: val_loss improved from 0.98318 to 0.94898, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 2s 22ms/step - loss: 0.7605 - accuracy: 0.7456 - val_loss: 0.9490 - val_accuracy: 0.6962 - lr: 0.0010
# Epoch 21/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.7799 - accuracy: 0.7335
# Epoch 21: val_loss did not improve from 0.94898
# 92/92 [==============================] - 2s 24ms/step - loss: 0.7781 - accuracy: 0.7340 - val_loss: 1.0653 - val_accuracy: 0.6458 - lr: 0.0010
# Epoch 22/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.7442 - accuracy: 0.7486
# Epoch 22: val_loss did not improve from 0.94898
# 92/92 [==============================] - 2s 24ms/step - loss: 0.7426 - accuracy: 0.7486 - val_loss: 1.1923 - val_accuracy: 0.6553 - lr: 0.0010
# Epoch 23/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.7488 - accuracy: 0.7493
# Epoch 23: val_loss did not improve from 0.94898
# 92/92 [==============================] - 3s 28ms/step - loss: 0.7467 - accuracy: 0.7500 - val_loss: 0.9870 - val_accuracy: 0.6757 - lr: 0.0010
# Epoch 24/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7426 - accuracy: 0.7646
# Epoch 24: val_loss did not improve from 0.94898
# 92/92 [==============================] - 2s 26ms/step - loss: 0.7426 - accuracy: 0.7646 - val_loss: 1.0497 - val_accuracy: 0.6649 - lr: 0.0010
# Epoch 25/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.7024 - accuracy: 0.7744
# Epoch 25: val_loss did not improve from 0.94898
# 92/92 [==============================] - 2s 21ms/step - loss: 0.7009 - accuracy: 0.7749 - val_loss: 1.6379 - val_accuracy: 0.5313 - lr: 0.0010
# Epoch 26/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.7170 - accuracy: 0.7679
# Epoch 26: val_loss did not improve from 0.94898
# 92/92 [==============================] - 2s 21ms/step - loss: 0.7142 - accuracy: 0.7687 - val_loss: 1.1832 - val_accuracy: 0.6335 - lr: 0.0010
# Epoch 27/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.7035 - accuracy: 0.7682
# Epoch 27: val_loss did not improve from 0.94898
# 92/92 [==============================] - 2s 24ms/step - loss: 0.7009 - accuracy: 0.7691 - val_loss: 1.2432 - val_accuracy: 0.6213 - lr: 0.0010
# Epoch 28/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.7830
# Epoch 28: val_loss did not improve from 0.94898
# 92/92 [==============================] - 2s 23ms/step - loss: 0.6842 - accuracy: 0.7841 - val_loss: 0.9668 - val_accuracy: 0.7166 - lr: 0.0010
# Epoch 29/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.7713
# Epoch 29: val_loss did not improve from 0.94898
# 92/92 [==============================] - 2s 22ms/step - loss: 0.7049 - accuracy: 0.7721 - val_loss: 1.2345 - val_accuracy: 0.6172 - lr: 0.0010
# Epoch 30/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6929 - accuracy: 0.7799
# Epoch 30: val_loss improved from 0.94898 to 0.87102, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 2s 22ms/step - loss: 0.6912 - accuracy: 0.7803 - val_loss: 0.8710 - val_accuracy: 0.7343 - lr: 0.0010
# Epoch 31/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6798 - accuracy: 0.7823
# Epoch 31: val_loss did not improve from 0.87102
# 92/92 [==============================] - 2s 21ms/step - loss: 0.6775 - accuracy: 0.7837 - val_loss: 0.9211 - val_accuracy: 0.7071 - lr: 0.0010
# Epoch 32/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6766 - accuracy: 0.7826
# Epoch 32: val_loss did not improve from 0.87102
# 92/92 [==============================] - 2s 21ms/step - loss: 0.6744 - accuracy: 0.7837 - val_loss: 1.0252 - val_accuracy: 0.6853 - lr: 0.0010
# Epoch 33/150
# 90/92 [============================>.] - ETA: 0s - loss: 0.6589 - accuracy: 0.7997
# Epoch 33: val_loss did not improve from 0.87102
# 92/92 [==============================] - 2s 22ms/step - loss: 0.6562 - accuracy: 0.8007 - val_loss: 0.9409 - val_accuracy: 0.6921 - lr: 0.0010
# Epoch 34/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6452 - accuracy: 0.7995
# Epoch 34: val_loss did not improve from 0.87102
# 92/92 [==============================] - 2s 24ms/step - loss: 0.6427 - accuracy: 0.8011 - val_loss: 0.9287 - val_accuracy: 0.7030 - lr: 0.0010
# Epoch 35/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6461 - accuracy: 0.8039
# Epoch 35: val_loss improved from 0.87102 to 0.85626, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 2s 23ms/step - loss: 0.6437 - accuracy: 0.8052 - val_loss: 0.8563 - val_accuracy: 0.7302 - lr: 0.0010
# Epoch 36/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6474 - accuracy: 0.8060
# Epoch 36: val_loss did not improve from 0.85626
# 92/92 [==============================] - 2s 21ms/step - loss: 0.6448 - accuracy: 0.8072 - val_loss: 0.8946 - val_accuracy: 0.7221 - lr: 0.0010
# Epoch 37/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6366 - accuracy: 0.8073
# Epoch 37: val_loss did not improve from 0.85626
# 92/92 [==============================] - 2s 22ms/step - loss: 0.6353 - accuracy: 0.8079 - val_loss: 0.9340 - val_accuracy: 0.7153 - lr: 0.0010
# Epoch 38/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6426 - accuracy: 0.8019
# Epoch 38: val_loss did not improve from 0.85626
# 92/92 [==============================] - 2s 21ms/step - loss: 0.6402 - accuracy: 0.8031 - val_loss: 0.8988 - val_accuracy: 0.7193 - lr: 0.0010
# Epoch 39/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6448 - accuracy: 0.8008
# Epoch 39: val_loss did not improve from 0.85626
# 92/92 [==============================] - 2s 22ms/step - loss: 0.6423 - accuracy: 0.8021 - val_loss: 0.8940 - val_accuracy: 0.7234 - lr: 0.0010
# Epoch 40/150
# 90/92 [============================>.] - ETA: 0s - loss: 0.6300 - accuracy: 0.8031
# Epoch 40: val_loss did not improve from 0.85626
# 92/92 [==============================] - 2s 25ms/step - loss: 0.6259 - accuracy: 0.8048 - val_loss: 0.8992 - val_accuracy: 0.7112 - lr: 0.0010
# Epoch 41/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6309 - accuracy: 0.8166
# Epoch 41: val_loss did not improve from 0.85626
# 92/92 [==============================] - 2s 22ms/step - loss: 0.6281 - accuracy: 0.8181 - val_loss: 0.8849 - val_accuracy: 0.7248 - lr: 0.0010
# Epoch 42/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6160 - accuracy: 0.8231
# Epoch 42: val_loss did not improve from 0.85626
# 92/92 [==============================] - 2s 21ms/step - loss: 0.6135 - accuracy: 0.8246 - val_loss: 1.0437 - val_accuracy: 0.6526 - lr: 0.0010
# Epoch 43/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6204 - accuracy: 0.8262
# Epoch 43: val_loss did not improve from 0.85626
# 92/92 [==============================] - 2s 21ms/step - loss: 0.6189 - accuracy: 0.8266 - val_loss: 0.8698 - val_accuracy: 0.7302 - lr: 0.0010
# Epoch 44/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6141 - accuracy: 0.8207
# Epoch 44: val_loss did not improve from 0.85626
# 92/92 [==============================] - 2s 22ms/step - loss: 0.6124 - accuracy: 0.8215 - val_loss: 1.0662 - val_accuracy: 0.6594 - lr: 0.0010
# Epoch 45/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.6234 - accuracy: 0.8056Restoring model weights from the end of the best epoch: 35.
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 45: val_loss did not improve from 0.85626
# 92/92 [==============================] - 2s 22ms/step - loss: 0.6216 - accuracy: 0.8065 - val_loss: 1.0120 - val_accuracy: 0.7098 - lr: 0.0010
# Epoch 45: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_rotation_1 (RandomR  (None, 190, 190, 3)       0
#  otation)
#
#  rescaling (Rescaling)       (None, 190, 190, 3)       0
#
#  conv2d (Conv2D)             (None, 188, 188, 8)       224
#
#  batch_normalization (Batch  (None, 188, 188, 8)       32
#  Normalization)
#
#  activation (Activation)     (None, 188, 188, 8)       0
#
#  max_pooling2d (MaxPooling2  (None, 94, 94, 8)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 92, 92, 16)        1168
#
#  activation_1 (Activation)   (None, 92, 92, 16)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 46, 46, 16)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 44, 44, 32)        4640
#
#  activation_2 (Activation)   (None, 44, 44, 32)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 64)        18496
#
#  activation_3 (Activation)   (None, 20, 20, 64)        0
#
#  max_pooling2d_3 (MaxPoolin  (None, 10, 10, 64)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  activation_4 (Activation)   (None, 8, 8, 128)         0
#
#  max_pooling2d_4 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 2, 2, 256)         295168
#
#  activation_5 (Activation)   (None, 2, 2, 256)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 256)               262400
#
#  activation_6 (Activation)   (None, 256)               0
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 657269 (2.51 MB)
# Trainable params: 657253 (2.51 MB)
# Non-trainable params: 16 (64.00 Byte)
# _________________________________________________________________

# %%
###-----------------------------------
### Function to plot Loss Curve
###-----------------------------------

def fn_plot_tf_hist(hist_df):
    '''
    Args:
      hist_df : pandas Dataframe with four columns
                For 'x' values, we will use index
    '''
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12

    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]

    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(y1.capitalize(),
                           hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y3].to_numpy()[0]), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)

    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(y2.capitalize(),
                           hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y4].to_numpy()[0]), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow


    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')

    plt.tight_layout()

# %%
loss_df = pd.DataFrame(history.history)
fn_plot_tf_hist(loss_df)

# %%
loss_df[loss_df['val_loss'] == loss_df['val_loss'].min()]
# Out:
#         loss  accuracy  val_loss  val_accuracy     lr
# 34  0.643739  0.805177  0.856256      0.730245  0.001
