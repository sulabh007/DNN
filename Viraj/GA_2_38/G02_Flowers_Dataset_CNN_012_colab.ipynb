# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
#
# ## Convolutional Neural Network
# ### Flower Dataset

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from collections.abc import Callable
from typing import Literal
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %matplotlib inline

# %%
gpus = tf.config.list_physical_devices('GPU')

try:
    for g in gpus:
        tf.config.experimental.set_memory_growth(g, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print (len(gpus), 'Phusical GPUs', len(logical_gpus), 'Logical GPUs')
except:
    print ('invalid device')
# Out:
# 1 Phusical GPUs 1 Logical GPUs

# %%
###----------------
### Some parameters
###----------------

inpDir = '/home/dai/Documents/DNN/7.DNN/input'
outDir = '../output'
modelDir = '../models'
subDir = 'flower_photos'
altName = 'cnn_base'

RANDOM_STATE = 24 # REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results


EPOCHS = 150 # number of epochs
ALPHA = 0.001 # learning rate
TEST_SIZE = 0.2
BATCH_SIZE = 32
LR_PATIENCE = 10
FACTOR_LR = 0.5
PATIENCE = 20
IMG_HEIGHT = 194
IMG_WIDTH = 194

# parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

CMAP = 'coolwarm' # plt.cm.Spectral

plt.rcParams.update(params)

# %%
def fn_plot_label(tr_ds , ts_ds):

    plt.figure(figsize=(15,5)) # instantiate the figure

    plt.subplot(1, 2, 1) # first out of 2

    train_labels = tf.concat([lbl for img, lbl in tr_ds], axis= 0).numpy() # get the lables

    unique, _, counts = tf.unique_with_counts(train_labels) # get counts

    plt.bar(range(len(unique)), counts, align='center', color= 'DarkBlue') # barplot the count

    plt.xticks(range(len(unique)), class_names)

    plt.title('Traning Set')

    plt.subplot(1, 2, 2)

    test_labels = tf.concat([lbl for img, lbl in ts_ds], axis= 0).numpy()

    unique, _, counts = tf.unique_with_counts(test_labels)

    plt.bar(range(len(unique)), counts, align='center', color= 'Orange')

    plt.xticks(range(len(unique)), class_names)

    plt.title('Test Set')

# %% [markdown]
# ### Using Flowers Data

# %% [markdown]
# Coverting to Datasets from a directory

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

data_dir = tf.keras.utils.get_file(origin=dataset_url,
                                  fname='flower_photos',
                                  untar=True)

data_dir = pathlib.Path(data_dir)

# %%
data_dir
# Out:
# PosixPath('/root/.keras/datasets/flower_photos')

# %%
os.listdir(data_dir)
# Out:
# ['tulips', 'daisy', 'LICENSE.txt', 'sunflowers', 'roses', 'dandelion']

# %%
#create traning data
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, #path to the data directory
    validation_split = TEST_SIZE, #what ratio of validation data
    subset = 'training', #purpose
    seed = RANDOM_STATE,
    image_size = [IMG_HEIGHT, IMG_WIDTH],
    batch_size = BATCH_SIZE
)

#create test data
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, #path to the data directory
    validation_split = TEST_SIZE, #what ratio of validation data
    subset = 'validation', #purpose
    seed = RANDOM_STATE,
    image_size = [IMG_HEIGHT, IMG_WIDTH],
    batch_size = BATCH_SIZE
)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
# is it picking class names
class_names = train_ds.class_names
class_names
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
plt.figure(figsize=(15,6))

for images, labels in train_ds.take(1): # get me one batch

    for i in range (BATCH_SIZE): #loop over batch

        plt.subplot(int(BATCH_SIZE/8),8, i+1) # access the axis

        plt.grid(False)

        plt.imshow(images[i].numpy().astype('uint8')) # show image convert to numpy and int

        plt.title(class_names[labels[i]])

        plt.axis('off')

    plt.show()

# %%
plt.figure(figsize=(15,6))

for images, labels in test_ds.take(1): # get me one batch

    for i in range (BATCH_SIZE): #loop over batch

        plt.subplot(int(BATCH_SIZE/8),8, i+1) # access the axis

        plt.grid(False)

        plt.imshow(images[i].numpy().astype('uint8')) # show image convert to numpy and int

        plt.title(class_names[labels[i]])

        plt.axis('off')

    plt.show()

# %%
fn_plot_label(train_ds, test_ds)

# %%
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

# %% [markdown]
# ## Random Zoom

# %%
layer = tf.keras.layers.RandomZoom(height_factor=(-0.2, -0.2),
                                   width_factor=(-0.2, -0.2))

plt.figure()

img_num = 3

for images, labels in test_ds.take(1): # get me one batch

    out_images = layer(images)

    plt.subplot(1, 2, 1)
    plt.title('Orignal')
    plt.imshow(images[img_num].numpy().astype('uint8'))

    plt.subplot(1, 2, 2)
    plt.title('Zoomed')
    plt.imshow(out_images[img_num].numpy().astype('uint8'))

# %%
layer = tf.keras.layers.RandomRotation((-0.2, 0.3))

plt.figure()

img_num = 3

for images, labels in test_ds.take(1): # get me one batch

    out_images = layer(images)

    plt.subplot(1, 2, 1)
    plt.title('Orignal')
    plt.imshow(images[img_num].numpy().astype('uint8'))

    plt.subplot(1, 2, 2)
    plt.title('Rotated')
    plt.imshow(out_images[img_num].numpy().astype('uint8'))

# %%
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

test_ds = test_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Build model
dor1 = 0.01
#knl_reg = tf.keras.regularizers.L2(l2 = 0)
model = tf.keras.Sequential()

# model.add(tf.keras.layers.RandomZoom(height_factor=(-0.2, -0.2), width_factor=(-0.2, -0.2)))



model.add(tf.keras.layers.Rescaling(1/255.)), # Convert between 0 and 1
model.add(tf.keras.layers.RandomFlip("horizontal"))
model.add(tf.keras.layers.RandomRotation((-0.2, 0.3)))

###-------
### Set 1
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(32, (3,3))), # 188 x 188 x 8

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 94 x 94 x 8

###-------
### Set 2
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(64, (3,3))), # 92 x 92 x 16

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# Conv layer
model.add(tf.keras.layers.Conv2D(128, (3,3))), # 92 x 92 x 16

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),
# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 46 x 46 x 16

###-------
### Set 3
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(256, (3,3))), # 44 x 44 x 32

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 22 x 22 x 32

###-------
### Set 4
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(512, (3,3))), # 20 x 20 x 64

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 10 x 10 x 64

###-------
### Set 5
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(1024, (3,3))), # 8 x 8 x 128

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 4 x 4 x 128

###-------
### Set 6
###-------

model.add(tf.keras.layers.Conv2D(2048, (3,3))), # 2 x 2 x 256

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
###------------
### Head Start
###------------
model.add(tf.keras.layers.Flatten()), # Flatten

model.add(tf.keras.layers.Dense(2048)), # Dense 1

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))

model.add(tf.keras.layers.Dense(5)) #Output

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE,
    mode = 'auto',
    baseline = None,
    verbose=1,
    restore_best_weights=True,
    start_from_epoch=0,
)
lr_decay = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=FACTOR_LR,
    patience=LR_PATIENCE,
    verbose=1,
    mode='auto',

)

#define model file path
modelFile = os.path.join(modelDir, subDir, altName)

#define checkpoint callback
model_callback = tf.keras.callbacks.ModelCheckpoint(
    modelFile,
    monitor = 'val_loss',
    verbose = 1,
    save_best_only = True,
    save_weights_only = True,
    mode = 'auto'
)

# %%
optim = tf.keras.optimizers.AdamW(learning_rate = ALPHA)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

model.compile(optimizer = optim, loss = loss_fn, metrics = ['accuracy'])

# %%
history = model.fit(train_ds, validation_data=test_ds,
                    epochs=EPOCHS, verbose = 1,
                    batch_size=BATCH_SIZE,
                    callbacks=[early_stopping, lr_decay, model_callback])
# Out:
# Epoch 1/150
# 92/92 [==============================] - ETA: 0s - loss: 1.6237 - accuracy: 0.2698
# Epoch 1: val_loss improved from inf to 1.49608, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 34s 245ms/step - loss: 1.6237 - accuracy: 0.2698 - val_loss: 1.4961 - val_accuracy: 0.2371 - lr: 0.0010
# Epoch 2/150
# 92/92 [==============================] - ETA: 0s - loss: 1.4112 - accuracy: 0.3719
# Epoch 2: val_loss improved from 1.49608 to 1.37852, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 155ms/step - loss: 1.4112 - accuracy: 0.3719 - val_loss: 1.3785 - val_accuracy: 0.3965 - lr: 0.0010
# Epoch 3/150
# 92/92 [==============================] - ETA: 0s - loss: 1.3236 - accuracy: 0.4278
# Epoch 3: val_loss improved from 1.37852 to 1.33372, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 149ms/step - loss: 1.3236 - accuracy: 0.4278 - val_loss: 1.3337 - val_accuracy: 0.4373 - lr: 0.0010
# Epoch 4/150
# 92/92 [==============================] - ETA: 0s - loss: 1.2629 - accuracy: 0.4384
# Epoch 4: val_loss did not improve from 1.33372
# 92/92 [==============================] - 12s 125ms/step - loss: 1.2629 - accuracy: 0.4384 - val_loss: 1.3601 - val_accuracy: 0.4169 - lr: 0.0010
# Epoch 5/150
# 92/92 [==============================] - ETA: 0s - loss: 1.2148 - accuracy: 0.4683
# Epoch 5: val_loss improved from 1.33372 to 1.21882, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 149ms/step - loss: 1.2148 - accuracy: 0.4683 - val_loss: 1.2188 - val_accuracy: 0.4700 - lr: 0.0010
# Epoch 6/150
# 92/92 [==============================] - ETA: 0s - loss: 1.1292 - accuracy: 0.5412
# Epoch 6: val_loss improved from 1.21882 to 1.04366, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 148ms/step - loss: 1.1292 - accuracy: 0.5412 - val_loss: 1.0437 - val_accuracy: 0.5926 - lr: 0.0010
# Epoch 7/150
# 92/92 [==============================] - ETA: 0s - loss: 0.9698 - accuracy: 0.6059
# Epoch 7: val_loss improved from 1.04366 to 1.02450, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 18s 194ms/step - loss: 0.9698 - accuracy: 0.6059 - val_loss: 1.0245 - val_accuracy: 0.5899 - lr: 0.0010
# Epoch 8/150
# 92/92 [==============================] - ETA: 0s - loss: 0.8790 - accuracy: 0.6424
# Epoch 8: val_loss improved from 1.02450 to 0.95128, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 150ms/step - loss: 0.8790 - accuracy: 0.6424 - val_loss: 0.9513 - val_accuracy: 0.6226 - lr: 0.0010
# Epoch 9/150
# 92/92 [==============================] - ETA: 0s - loss: 0.8561 - accuracy: 0.6488
# Epoch 9: val_loss improved from 0.95128 to 0.92657, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 155ms/step - loss: 0.8561 - accuracy: 0.6488 - val_loss: 0.9266 - val_accuracy: 0.6281 - lr: 0.0010
# Epoch 10/150
# 92/92 [==============================] - ETA: 0s - loss: 0.8380 - accuracy: 0.6672
# Epoch 10: val_loss improved from 0.92657 to 0.86584, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 148ms/step - loss: 0.8380 - accuracy: 0.6672 - val_loss: 0.8658 - val_accuracy: 0.6649 - lr: 0.0010
# Epoch 11/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7856 - accuracy: 0.6873
# Epoch 11: val_loss improved from 0.86584 to 0.82237, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7856 - accuracy: 0.6873 - val_loss: 0.8224 - val_accuracy: 0.6853 - lr: 0.0010
# Epoch 12/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7895 - accuracy: 0.6952
# Epoch 12: val_loss improved from 0.82237 to 0.80077, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7895 - accuracy: 0.6952 - val_loss: 0.8008 - val_accuracy: 0.6826 - lr: 0.0010
# Epoch 13/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7446 - accuracy: 0.6955
# Epoch 13: val_loss did not improve from 0.80077
# 92/92 [==============================] - 11s 124ms/step - loss: 0.7446 - accuracy: 0.6955 - val_loss: 0.8040 - val_accuracy: 0.6744 - lr: 0.0010
# Epoch 14/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7559 - accuracy: 0.7027
# Epoch 14: val_loss improved from 0.80077 to 0.79964, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7559 - accuracy: 0.7027 - val_loss: 0.7996 - val_accuracy: 0.6826 - lr: 0.0010
# Epoch 15/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7263 - accuracy: 0.7129
# Epoch 15: val_loss improved from 0.79964 to 0.79487, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7263 - accuracy: 0.7129 - val_loss: 0.7949 - val_accuracy: 0.6812 - lr: 0.0010
# Epoch 16/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7090 - accuracy: 0.7173
# Epoch 16: val_loss did not improve from 0.79487
# 92/92 [==============================] - 12s 125ms/step - loss: 0.7090 - accuracy: 0.7173 - val_loss: 0.8189 - val_accuracy: 0.6935 - lr: 0.0010
# Epoch 17/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6801 - accuracy: 0.7333
# Epoch 17: val_loss improved from 0.79487 to 0.74789, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 149ms/step - loss: 0.6801 - accuracy: 0.7333 - val_loss: 0.7479 - val_accuracy: 0.6975 - lr: 0.0010
# Epoch 18/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6585 - accuracy: 0.7408
# Epoch 18: val_loss did not improve from 0.74789
# 92/92 [==============================] - 11s 124ms/step - loss: 0.6585 - accuracy: 0.7408 - val_loss: 0.7642 - val_accuracy: 0.7003 - lr: 0.0010
# Epoch 19/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6474 - accuracy: 0.7548
# Epoch 19: val_loss improved from 0.74789 to 0.73790, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 149ms/step - loss: 0.6474 - accuracy: 0.7548 - val_loss: 0.7379 - val_accuracy: 0.7166 - lr: 0.0010
# Epoch 20/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6516 - accuracy: 0.7503
# Epoch 20: val_loss improved from 0.73790 to 0.71456, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 155ms/step - loss: 0.6516 - accuracy: 0.7503 - val_loss: 0.7146 - val_accuracy: 0.7180 - lr: 0.0010
# Epoch 21/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6253 - accuracy: 0.7520
# Epoch 21: val_loss improved from 0.71456 to 0.70318, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 149ms/step - loss: 0.6253 - accuracy: 0.7520 - val_loss: 0.7032 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 22/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6068 - accuracy: 0.7650
# Epoch 22: val_loss did not improve from 0.70318
# 92/92 [==============================] - 12s 125ms/step - loss: 0.6068 - accuracy: 0.7650 - val_loss: 0.7115 - val_accuracy: 0.7071 - lr: 0.0010
# Epoch 23/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5945 - accuracy: 0.7663
# Epoch 23: val_loss did not improve from 0.70318
# 92/92 [==============================] - 11s 124ms/step - loss: 0.5945 - accuracy: 0.7663 - val_loss: 0.7203 - val_accuracy: 0.7248 - lr: 0.0010
# Epoch 24/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5979 - accuracy: 0.7681
# Epoch 24: val_loss improved from 0.70318 to 0.70085, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 19s 205ms/step - loss: 0.5979 - accuracy: 0.7681 - val_loss: 0.7008 - val_accuracy: 0.7398 - lr: 0.0010
# Epoch 25/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5728 - accuracy: 0.7769
# Epoch 25: val_loss did not improve from 0.70085
# 92/92 [==============================] - 11s 124ms/step - loss: 0.5728 - accuracy: 0.7769 - val_loss: 0.7030 - val_accuracy: 0.7411 - lr: 0.0010
# Epoch 26/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5760 - accuracy: 0.7762
# Epoch 26: val_loss did not improve from 0.70085
# 92/92 [==============================] - 11s 124ms/step - loss: 0.5760 - accuracy: 0.7762 - val_loss: 0.7405 - val_accuracy: 0.7057 - lr: 0.0010
# Epoch 27/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5681 - accuracy: 0.7817
# Epoch 27: val_loss improved from 0.70085 to 0.69920, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 149ms/step - loss: 0.5681 - accuracy: 0.7817 - val_loss: 0.6992 - val_accuracy: 0.7452 - lr: 0.0010
# Epoch 28/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5530 - accuracy: 0.7933
# Epoch 28: val_loss did not improve from 0.69920
# 92/92 [==============================] - 12s 125ms/step - loss: 0.5530 - accuracy: 0.7933 - val_loss: 0.7263 - val_accuracy: 0.7207 - lr: 0.0010
# Epoch 29/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5554 - accuracy: 0.7827
# Epoch 29: val_loss improved from 0.69920 to 0.69209, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 149ms/step - loss: 0.5554 - accuracy: 0.7827 - val_loss: 0.6921 - val_accuracy: 0.7452 - lr: 0.0010
# Epoch 30/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5469 - accuracy: 0.7810
# Epoch 30: val_loss did not improve from 0.69209
# 92/92 [==============================] - 11s 124ms/step - loss: 0.5469 - accuracy: 0.7810 - val_loss: 0.7149 - val_accuracy: 0.7425 - lr: 0.0010
# Epoch 31/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5449 - accuracy: 0.7902
# Epoch 31: val_loss did not improve from 0.69209
# 92/92 [==============================] - 11s 125ms/step - loss: 0.5449 - accuracy: 0.7902 - val_loss: 0.7455 - val_accuracy: 0.7221 - lr: 0.0010
# Epoch 32/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5015 - accuracy: 0.8031
# Epoch 32: val_loss improved from 0.69209 to 0.67126, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 149ms/step - loss: 0.5015 - accuracy: 0.8031 - val_loss: 0.6713 - val_accuracy: 0.7425 - lr: 0.0010
# Epoch 33/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4933 - accuracy: 0.8154
# Epoch 33: val_loss did not improve from 0.67126
# 92/92 [==============================] - 11s 124ms/step - loss: 0.4933 - accuracy: 0.8154 - val_loss: 0.7364 - val_accuracy: 0.7302 - lr: 0.0010
# Epoch 34/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4931 - accuracy: 0.8069
# Epoch 34: val_loss did not improve from 0.67126
# 92/92 [==============================] - 12s 125ms/step - loss: 0.4931 - accuracy: 0.8069 - val_loss: 0.7079 - val_accuracy: 0.7371 - lr: 0.0010
# Epoch 35/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4802 - accuracy: 0.8130
# Epoch 35: val_loss did not improve from 0.67126
# 92/92 [==============================] - 12s 126ms/step - loss: 0.4802 - accuracy: 0.8130 - val_loss: 0.7004 - val_accuracy: 0.7466 - lr: 0.0010
# Epoch 36/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4706 - accuracy: 0.8168
# Epoch 36: val_loss did not improve from 0.67126
# 92/92 [==============================] - 12s 125ms/step - loss: 0.4706 - accuracy: 0.8168 - val_loss: 0.7430 - val_accuracy: 0.7248 - lr: 0.0010
# Epoch 37/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4758 - accuracy: 0.8110
# Epoch 37: val_loss did not improve from 0.67126
# 92/92 [==============================] - 12s 125ms/step - loss: 0.4758 - accuracy: 0.8110 - val_loss: 0.6845 - val_accuracy: 0.7466 - lr: 0.0010
# Epoch 38/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4436 - accuracy: 0.8386
# Epoch 38: val_loss improved from 0.67126 to 0.66326, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 19s 205ms/step - loss: 0.4436 - accuracy: 0.8386 - val_loss: 0.6633 - val_accuracy: 0.7357 - lr: 0.0010
# Epoch 39/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4539 - accuracy: 0.8239
# Epoch 39: val_loss improved from 0.66326 to 0.65871, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 150ms/step - loss: 0.4539 - accuracy: 0.8239 - val_loss: 0.6587 - val_accuracy: 0.7357 - lr: 0.0010
# Epoch 40/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4089 - accuracy: 0.8430
# Epoch 40: val_loss did not improve from 0.65871
# 92/92 [==============================] - 12s 131ms/step - loss: 0.4089 - accuracy: 0.8430 - val_loss: 0.7496 - val_accuracy: 0.7643 - lr: 0.0010
# Epoch 41/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4216 - accuracy: 0.8304
# Epoch 41: val_loss did not improve from 0.65871
# 92/92 [==============================] - 12s 126ms/step - loss: 0.4216 - accuracy: 0.8304 - val_loss: 0.7171 - val_accuracy: 0.7466 - lr: 0.0010
# Epoch 42/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4029 - accuracy: 0.8392
# Epoch 42: val_loss did not improve from 0.65871
# 92/92 [==============================] - 12s 126ms/step - loss: 0.4029 - accuracy: 0.8392 - val_loss: 0.7142 - val_accuracy: 0.7520 - lr: 0.0010
# Epoch 43/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4214 - accuracy: 0.8454
# Epoch 43: val_loss did not improve from 0.65871
# 92/92 [==============================] - 12s 125ms/step - loss: 0.4214 - accuracy: 0.8454 - val_loss: 0.7582 - val_accuracy: 0.7139 - lr: 0.0010
# Epoch 44/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3880 - accuracy: 0.8447
# Epoch 44: val_loss did not improve from 0.65871
# 92/92 [==============================] - 12s 125ms/step - loss: 0.3880 - accuracy: 0.8447 - val_loss: 0.7907 - val_accuracy: 0.7520 - lr: 0.0010
# Epoch 45/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3832 - accuracy: 0.8522
# Epoch 45: val_loss did not improve from 0.65871
# 92/92 [==============================] - 11s 125ms/step - loss: 0.3832 - accuracy: 0.8522 - val_loss: 0.9288 - val_accuracy: 0.7398 - lr: 0.0010
# Epoch 46/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3944 - accuracy: 0.8484
# Epoch 46: val_loss did not improve from 0.65871
# 92/92 [==============================] - 11s 125ms/step - loss: 0.3944 - accuracy: 0.8484 - val_loss: 0.8966 - val_accuracy: 0.7234 - lr: 0.0010
# Epoch 47/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3696 - accuracy: 0.8508
# Epoch 47: val_loss did not improve from 0.65871
# 92/92 [==============================] - 11s 125ms/step - loss: 0.3696 - accuracy: 0.8508 - val_loss: 0.8151 - val_accuracy: 0.7316 - lr: 0.0010
# Epoch 48/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3606 - accuracy: 0.8614
# Epoch 48: val_loss did not improve from 0.65871
# 92/92 [==============================] - 11s 125ms/step - loss: 0.3606 - accuracy: 0.8614 - val_loss: 0.8042 - val_accuracy: 0.7480 - lr: 0.0010
# Epoch 49/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3699 - accuracy: 0.8597
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 49: val_loss did not improve from 0.65871
# 92/92 [==============================] - 12s 125ms/step - loss: 0.3699 - accuracy: 0.8597 - val_loss: 0.7508 - val_accuracy: 0.7575 - lr: 0.0010
# Epoch 50/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3123 - accuracy: 0.8723
# Epoch 50: val_loss did not improve from 0.65871
# 92/92 [==============================] - 12s 125ms/step - loss: 0.3123 - accuracy: 0.8723 - val_loss: 0.8311 - val_accuracy: 0.7480 - lr: 5.0000e-04
# Epoch 51/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.8927
# Epoch 51: val_loss did not improve from 0.65871
# 92/92 [==============================] - 12s 126ms/step - loss: 0.2767 - accuracy: 0.8927 - val_loss: 0.8560 - val_accuracy: 0.7548 - lr: 5.0000e-04
# Epoch 52/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2777 - accuracy: 0.8876
# Epoch 52: val_loss did not improve from 0.65871
# 92/92 [==============================] - 11s 124ms/step - loss: 0.2777 - accuracy: 0.8876 - val_loss: 0.8603 - val_accuracy: 0.7507 - lr: 5.0000e-04
# Epoch 53/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2478 - accuracy: 0.9063
# Epoch 53: val_loss did not improve from 0.65871
# 92/92 [==============================] - 11s 125ms/step - loss: 0.2478 - accuracy: 0.9063 - val_loss: 0.7947 - val_accuracy: 0.7779 - lr: 5.0000e-04
# Epoch 54/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2783 - accuracy: 0.8927
# Epoch 54: val_loss did not improve from 0.65871
# 92/92 [==============================] - 12s 126ms/step - loss: 0.2783 - accuracy: 0.8927 - val_loss: 0.7656 - val_accuracy: 0.7575 - lr: 5.0000e-04
# Epoch 55/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2307 - accuracy: 0.9070
# Epoch 55: val_loss did not improve from 0.65871
# 92/92 [==============================] - 11s 125ms/step - loss: 0.2307 - accuracy: 0.9070 - val_loss: 0.9284 - val_accuracy: 0.7466 - lr: 5.0000e-04
# Epoch 56/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2282 - accuracy: 0.9152
# Epoch 56: val_loss did not improve from 0.65871
# 92/92 [==============================] - 12s 125ms/step - loss: 0.2282 - accuracy: 0.9152 - val_loss: 0.9265 - val_accuracy: 0.7507 - lr: 5.0000e-04
# Epoch 57/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2225 - accuracy: 0.9135
# Epoch 57: val_loss did not improve from 0.65871
# 92/92 [==============================] - 12s 125ms/step - loss: 0.2225 - accuracy: 0.9135 - val_loss: 0.9365 - val_accuracy: 0.7684 - lr: 5.0000e-04
# Epoch 58/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.9189
# Epoch 58: val_loss did not improve from 0.65871
# 92/92 [==============================] - 12s 125ms/step - loss: 0.2217 - accuracy: 0.9189 - val_loss: 0.9861 - val_accuracy: 0.7643 - lr: 5.0000e-04
# Epoch 59/150
# 92/92 [==============================] - ETA: 0s - loss: 0.1970 - accuracy: 0.9268Restoring model weights from the end of the best epoch: 39.
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 59: val_loss did not improve from 0.65871
# 92/92 [==============================] - 12s 127ms/step - loss: 0.1970 - accuracy: 0.9268 - val_loss: 1.2215 - val_accuracy: 0.7480 - lr: 5.0000e-04
# Epoch 59: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 194, 194, 3)       0
#
#  random_flip (RandomFlip)    (None, 194, 194, 3)       0
#
#  random_rotation_1 (RandomR  (None, 194, 194, 3)       0
#  otation)
#
#  conv2d (Conv2D)             (None, 192, 192, 32)      896
#
#  activation (Activation)     (None, 192, 192, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 96, 96, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 94, 94, 64)        18496
#
#  activation_1 (Activation)   (None, 94, 94, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 92, 92, 128)       73856
#
#  activation_2 (Activation)   (None, 92, 92, 128)       0
#
#  max_pooling2d_1 (MaxPoolin  (None, 46, 46, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 44, 44, 256)       295168
#
#  activation_3 (Activation)   (None, 44, 44, 256)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 256)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 20, 20, 512)       1180160
#
#  activation_4 (Activation)   (None, 20, 20, 512)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 10, 10, 512)       0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 1024)        4719616
#
#  activation_5 (Activation)   (None, 8, 8, 1024)        0
#
#  max_pooling2d_4 (MaxPoolin  (None, 4, 4, 1024)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 2, 2, 2048)        18876416
#
#  activation_6 (Activation)   (None, 2, 2, 2048)        0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 2048)              16779264
#
#  activation_7 (Activation)   (None, 2048)              0
#
#  dense_1 (Dense)             (None, 5)                 10245
#
# =================================================================
# Total params: 41954117 (160.04 MB)
# Trainable params: 41954117 (160.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
###-----------------------------------
### Function to plot Loss Curve
###-----------------------------------

def fn_plot_tf_hist(hist_df):
    '''
    Args:
      hist_df : pandas Dataframe with four columns
                For 'x' values, we will use index
    '''
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12

    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]

    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(y1.capitalize(),
                           hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y3].to_numpy()[0]), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)

    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(y2.capitalize(),
                           hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y4].to_numpy()[0]), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow


    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')

    plt.tight_layout()

# %%
loss_df = pd.DataFrame(history.history)
fn_plot_tf_hist(loss_df)

# %%
loss_df[loss_df['val_loss'] == loss_df['val_loss'].min()]
# Out:
#         loss  accuracy  val_loss  val_accuracy     lr
# 38  0.453943   0.82391   0.65871      0.735695  0.001
