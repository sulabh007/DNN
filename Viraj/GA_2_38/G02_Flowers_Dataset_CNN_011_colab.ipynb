# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
#
# ## Convolutional Neural Network
# ### Flower Dataset

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from collections.abc import Callable
from typing import Literal
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %matplotlib inline

# %%
gpus = tf.config.list_physical_devices('GPU')

try:
    for g in gpus:
        tf.config.experimental.set_memory_growth(g, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print (len(gpus), 'Phusical GPUs', len(logical_gpus), 'Logical GPUs')
except:
    print ('invalid device')
# Out:
# 1 Phusical GPUs 1 Logical GPUs

# %%
###----------------
### Some parameters
###----------------

inpDir = '/home/dai/Documents/DNN/7.DNN/input'
outDir = '../output'
modelDir = '../models'
subDir = 'flower_photos'
altName = 'cnn_base'

RANDOM_STATE = 24 # REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results


EPOCHS = 150 # number of epochs
ALPHA = 0.001 # learning rate
TEST_SIZE = 0.2
BATCH_SIZE = 32
LR_PATIENCE = 10
FACTOR_LR = 0.5
PATIENCE = 20
IMG_HEIGHT = 190
IMG_WIDTH = 190

# parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

CMAP = 'coolwarm' # plt.cm.Spectral

plt.rcParams.update(params)

# %%
def fn_plot_label(tr_ds , ts_ds):

    plt.figure(figsize=(15,5)) # instantiate the figure

    plt.subplot(1, 2, 1) # first out of 2

    train_labels = tf.concat([lbl for img, lbl in tr_ds], axis= 0).numpy() # get the lables

    unique, _, counts = tf.unique_with_counts(train_labels) # get counts

    plt.bar(range(len(unique)), counts, align='center', color= 'DarkBlue') # barplot the count

    plt.xticks(range(len(unique)), class_names)

    plt.title('Traning Set')

    plt.subplot(1, 2, 2)

    test_labels = tf.concat([lbl for img, lbl in ts_ds], axis= 0).numpy()

    unique, _, counts = tf.unique_with_counts(test_labels)

    plt.bar(range(len(unique)), counts, align='center', color= 'Orange')

    plt.xticks(range(len(unique)), class_names)

    plt.title('Test Set')

# %% [markdown]
# ### Using Flowers Data

# %% [markdown]
# Coverting to Datasets from a directory

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

data_dir = tf.keras.utils.get_file(origin=dataset_url,
                                  fname='flower_photos',
                                  untar=True)

data_dir = pathlib.Path(data_dir)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228813984/228813984 [==============================] - 2s 0us/step

# %%
data_dir
# Out:
# PosixPath('/root/.keras/datasets/flower_photos')

# %%
os.listdir(data_dir)
# Out:
# ['tulips', 'daisy', 'LICENSE.txt', 'sunflowers', 'roses', 'dandelion']

# %%
#create traning data
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, #path to the data directory
    validation_split = TEST_SIZE, #what ratio of validation data
    subset = 'training', #purpose
    seed = RANDOM_STATE,
    image_size = [IMG_HEIGHT, IMG_WIDTH],
    batch_size = BATCH_SIZE
)

#create test data
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, #path to the data directory
    validation_split = TEST_SIZE, #what ratio of validation data
    subset = 'validation', #purpose
    seed = RANDOM_STATE,
    image_size = [IMG_HEIGHT, IMG_WIDTH],
    batch_size = BATCH_SIZE
)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
# is it picking class names
class_names = train_ds.class_names
class_names
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
plt.figure(figsize=(15,6))

for images, labels in train_ds.take(1): # get me one batch

    for i in range (BATCH_SIZE): #loop over batch

        plt.subplot(int(BATCH_SIZE/8),8, i+1) # access the axis

        plt.grid(False)

        plt.imshow(images[i].numpy().astype('uint8')) # show image convert to numpy and int

        plt.title(class_names[labels[i]])

        plt.axis('off')

    plt.show()

# %%
plt.figure(figsize=(15,6))

for images, labels in test_ds.take(1): # get me one batch

    for i in range (BATCH_SIZE): #loop over batch

        plt.subplot(int(BATCH_SIZE/8),8, i+1) # access the axis

        plt.grid(False)

        plt.imshow(images[i].numpy().astype('uint8')) # show image convert to numpy and int

        plt.title(class_names[labels[i]])

        plt.axis('off')

    plt.show()

# %%
fn_plot_label(train_ds, test_ds)

# %%
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

# %% [markdown]
# ## Random Zoom

# %%
layer = tf.keras.layers.RandomZoom(height_factor=(-0.2, -0.2),
                                   width_factor=(-0.2, -0.2))

plt.figure()

img_num = 3

for images, labels in test_ds.take(1): # get me one batch

    out_images = layer(images)

    plt.subplot(1, 2, 1)
    plt.title('Orignal')
    plt.imshow(images[img_num].numpy().astype('uint8'))

    plt.subplot(1, 2, 2)
    plt.title('Zoomed')
    plt.imshow(out_images[img_num].numpy().astype('uint8'))

# %%
layer = tf.keras.layers.RandomRotation((-0.2, 0.3))

plt.figure()

img_num = 3

for images, labels in test_ds.take(1): # get me one batch

    out_images = layer(images)

    plt.subplot(1, 2, 1)
    plt.title('Orignal')
    plt.imshow(images[img_num].numpy().astype('uint8'))

    plt.subplot(1, 2, 2)
    plt.title('Rotated')
    plt.imshow(out_images[img_num].numpy().astype('uint8'))

# %%
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

test_ds = test_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Build model
dor1 = 0.01
#knl_reg = tf.keras.regularizers.L2(l2 = 0)
model = tf.keras.Sequential()

# model.add(tf.keras.layers.RandomZoom(height_factor=(-0.2, -0.2), width_factor=(-0.2, -0.2)))



model.add(tf.keras.layers.Rescaling(1/255.)), # Convert between 0 and 1
model.add(tf.keras.layers.RandomFlip("horizontal"))
model.add(tf.keras.layers.RandomRotation((-0.2, 0.3)))

###-------
### Set 1
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(64, (3,3))), # 188 x 188 x 8

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 94 x 94 x 8

###-------
### Set 2
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(128, (3,3))), # 92 x 92 x 16

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 46 x 46 x 16

###-------
### Set 3
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(256, (3,3))), # 44 x 44 x 32

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 22 x 22 x 32

###-------
### Set 4
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(512, (3,3))), # 20 x 20 x 64

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 10 x 10 x 64

###-------
### Set 5
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(1024, (3,3))), # 8 x 8 x 128

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 4 x 4 x 128

###-------
### Set 6
###-------

model.add(tf.keras.layers.Conv2D(2048, (3,3))), # 2 x 2 x 256

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
###------------
### Head Start
###------------
model.add(tf.keras.layers.Flatten()), # Flatten

model.add(tf.keras.layers.Dense(2048)), # Dense 1

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))

model.add(tf.keras.layers.Dense(5)) #Output

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE,
    mode = 'auto',
    baseline = None,
    verbose=1,
    restore_best_weights=True,
    start_from_epoch=0,
)
lr_decay = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=FACTOR_LR,
    patience=LR_PATIENCE,
    verbose=1,
    mode='auto',

)

#define model file path
modelFile = os.path.join(modelDir, subDir, altName)

#define checkpoint callback
model_callback = tf.keras.callbacks.ModelCheckpoint(
    modelFile,
    monitor = 'val_loss',
    verbose = 1,
    save_best_only = True,
    save_weights_only = True,
    mode = 'auto'
)

# %%
optim = tf.keras.optimizers.AdamW(learning_rate = ALPHA)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

model.compile(optimizer = optim, loss = loss_fn, metrics = ['accuracy'])

# %%
history = model.fit(train_ds, validation_data=test_ds,
                    epochs=EPOCHS, verbose = 1,
                    batch_size=BATCH_SIZE,
                    callbacks=[early_stopping, lr_decay, model_callback])
# Out:
# Epoch 1/150
# 92/92 [==============================] - ETA: 0s - loss: 1.6764 - accuracy: 0.2803
# Epoch 1: val_loss improved from inf to 1.50388, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 31s 213ms/step - loss: 1.6764 - accuracy: 0.2803 - val_loss: 1.5039 - val_accuracy: 0.3147 - lr: 0.0010
# Epoch 2/150
# 92/92 [==============================] - ETA: 0s - loss: 1.2354 - accuracy: 0.4806
# Epoch 2: val_loss improved from 1.50388 to 1.13170, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 13s 140ms/step - loss: 1.2354 - accuracy: 0.4806 - val_loss: 1.1317 - val_accuracy: 0.5463 - lr: 0.0010
# Epoch 3/150
# 92/92 [==============================] - ETA: 0s - loss: 1.0795 - accuracy: 0.5456
# Epoch 3: val_loss did not improve from 1.13170
# 92/92 [==============================] - 11s 120ms/step - loss: 1.0795 - accuracy: 0.5456 - val_loss: 1.2058 - val_accuracy: 0.5027 - lr: 0.0010
# Epoch 4/150
# 92/92 [==============================] - ETA: 0s - loss: 1.0022 - accuracy: 0.5892
# Epoch 4: val_loss improved from 1.13170 to 1.05968, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 13s 141ms/step - loss: 1.0022 - accuracy: 0.5892 - val_loss: 1.0597 - val_accuracy: 0.5845 - lr: 0.0010
# Epoch 5/150
# 92/92 [==============================] - ETA: 0s - loss: 0.9311 - accuracy: 0.6311
# Epoch 5: val_loss improved from 1.05968 to 1.01848, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 13s 142ms/step - loss: 0.9311 - accuracy: 0.6311 - val_loss: 1.0185 - val_accuracy: 0.6090 - lr: 0.0010
# Epoch 6/150
# 92/92 [==============================] - ETA: 0s - loss: 0.8796 - accuracy: 0.6570
# Epoch 6: val_loss improved from 1.01848 to 0.93571, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 13s 142ms/step - loss: 0.8796 - accuracy: 0.6570 - val_loss: 0.9357 - val_accuracy: 0.6144 - lr: 0.0010
# Epoch 7/150
# 92/92 [==============================] - ETA: 0s - loss: 0.8455 - accuracy: 0.6635
# Epoch 7: val_loss improved from 0.93571 to 0.92211, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 13s 143ms/step - loss: 0.8455 - accuracy: 0.6635 - val_loss: 0.9221 - val_accuracy: 0.6485 - lr: 0.0010
# Epoch 8/150
# 92/92 [==============================] - ETA: 0s - loss: 0.8114 - accuracy: 0.6870
# Epoch 8: val_loss improved from 0.92211 to 0.89071, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 13s 144ms/step - loss: 0.8114 - accuracy: 0.6870 - val_loss: 0.8907 - val_accuracy: 0.6662 - lr: 0.0010
# Epoch 9/150
# 92/92 [==============================] - ETA: 0s - loss: 0.8006 - accuracy: 0.6843
# Epoch 9: val_loss improved from 0.89071 to 0.85553, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 13s 145ms/step - loss: 0.8006 - accuracy: 0.6843 - val_loss: 0.8555 - val_accuracy: 0.6757 - lr: 0.0010
# Epoch 10/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7570 - accuracy: 0.7054
# Epoch 10: val_loss improved from 0.85553 to 0.80779, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7570 - accuracy: 0.7054 - val_loss: 0.8078 - val_accuracy: 0.6866 - lr: 0.0010
# Epoch 11/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7366 - accuracy: 0.7101
# Epoch 11: val_loss did not improve from 0.80779
# 92/92 [==============================] - 11s 122ms/step - loss: 0.7366 - accuracy: 0.7101 - val_loss: 0.8624 - val_accuracy: 0.6730 - lr: 0.0010
# Epoch 12/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7297 - accuracy: 0.7231
# Epoch 12: val_loss improved from 0.80779 to 0.77094, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 18s 201ms/step - loss: 0.7297 - accuracy: 0.7231 - val_loss: 0.7709 - val_accuracy: 0.6866 - lr: 0.0010
# Epoch 13/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7155 - accuracy: 0.7200
# Epoch 13: val_loss improved from 0.77094 to 0.76600, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7155 - accuracy: 0.7200 - val_loss: 0.7660 - val_accuracy: 0.7112 - lr: 0.0010
# Epoch 14/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6906 - accuracy: 0.7275
# Epoch 14: val_loss improved from 0.76600 to 0.73787, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 13s 145ms/step - loss: 0.6906 - accuracy: 0.7275 - val_loss: 0.7379 - val_accuracy: 0.7139 - lr: 0.0010
# Epoch 15/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6606 - accuracy: 0.7415
# Epoch 15: val_loss did not improve from 0.73787
# 92/92 [==============================] - 11s 122ms/step - loss: 0.6606 - accuracy: 0.7415 - val_loss: 0.7675 - val_accuracy: 0.7112 - lr: 0.0010
# Epoch 16/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6547 - accuracy: 0.7490
# Epoch 16: val_loss did not improve from 0.73787
# 92/92 [==============================] - 11s 123ms/step - loss: 0.6547 - accuracy: 0.7490 - val_loss: 0.7398 - val_accuracy: 0.7003 - lr: 0.0010
# Epoch 17/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6539 - accuracy: 0.7408
# Epoch 17: val_loss did not improve from 0.73787
# 92/92 [==============================] - 11s 123ms/step - loss: 0.6539 - accuracy: 0.7408 - val_loss: 0.7500 - val_accuracy: 0.7112 - lr: 0.0010
# Epoch 18/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6270 - accuracy: 0.7646
# Epoch 18: val_loss improved from 0.73787 to 0.73282, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 19s 204ms/step - loss: 0.6270 - accuracy: 0.7646 - val_loss: 0.7328 - val_accuracy: 0.7153 - lr: 0.0010
# Epoch 19/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6052 - accuracy: 0.7681
# Epoch 19: val_loss did not improve from 0.73282
# 92/92 [==============================] - 11s 122ms/step - loss: 0.6052 - accuracy: 0.7681 - val_loss: 0.7481 - val_accuracy: 0.7084 - lr: 0.0010
# Epoch 20/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5946 - accuracy: 0.7681
# Epoch 20: val_loss did not improve from 0.73282
# 92/92 [==============================] - 11s 123ms/step - loss: 0.5946 - accuracy: 0.7681 - val_loss: 0.7358 - val_accuracy: 0.7262 - lr: 0.0010
# Epoch 21/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5600 - accuracy: 0.7881
# Epoch 21: val_loss did not improve from 0.73282
# 92/92 [==============================] - 11s 123ms/step - loss: 0.5600 - accuracy: 0.7881 - val_loss: 0.8022 - val_accuracy: 0.7016 - lr: 0.0010
# Epoch 22/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5838 - accuracy: 0.7728
# Epoch 22: val_loss improved from 0.73282 to 0.72047, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 19s 206ms/step - loss: 0.5838 - accuracy: 0.7728 - val_loss: 0.7205 - val_accuracy: 0.7439 - lr: 0.0010
# Epoch 23/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5267 - accuracy: 0.7912
# Epoch 23: val_loss improved from 0.72047 to 0.70119, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 14s 147ms/step - loss: 0.5267 - accuracy: 0.7912 - val_loss: 0.7012 - val_accuracy: 0.7466 - lr: 0.0010
# Epoch 24/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5284 - accuracy: 0.7922
# Epoch 24: val_loss did not improve from 0.70119
# 92/92 [==============================] - 11s 122ms/step - loss: 0.5284 - accuracy: 0.7922 - val_loss: 0.7070 - val_accuracy: 0.7330 - lr: 0.0010
# Epoch 25/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5126 - accuracy: 0.8021
# Epoch 25: val_loss did not improve from 0.70119
# 92/92 [==============================] - 11s 123ms/step - loss: 0.5126 - accuracy: 0.8021 - val_loss: 0.7361 - val_accuracy: 0.7316 - lr: 0.0010
# Epoch 26/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5200 - accuracy: 0.7950
# Epoch 26: val_loss did not improve from 0.70119
# 92/92 [==============================] - 11s 123ms/step - loss: 0.5200 - accuracy: 0.7950 - val_loss: 0.7459 - val_accuracy: 0.7316 - lr: 0.0010
# Epoch 27/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5133 - accuracy: 0.8007
# Epoch 27: val_loss improved from 0.70119 to 0.66852, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 18s 201ms/step - loss: 0.5133 - accuracy: 0.8007 - val_loss: 0.6685 - val_accuracy: 0.7439 - lr: 0.0010
# Epoch 28/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5040 - accuracy: 0.8048
# Epoch 28: val_loss did not improve from 0.66852
# 92/92 [==============================] - 11s 123ms/step - loss: 0.5040 - accuracy: 0.8048 - val_loss: 0.7108 - val_accuracy: 0.7466 - lr: 0.0010
# Epoch 29/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4506 - accuracy: 0.8168
# Epoch 29: val_loss did not improve from 0.66852
# 92/92 [==============================] - 11s 123ms/step - loss: 0.4506 - accuracy: 0.8168 - val_loss: 0.8127 - val_accuracy: 0.7466 - lr: 0.0010
# Epoch 30/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4607 - accuracy: 0.8239
# Epoch 30: val_loss did not improve from 0.66852
# 92/92 [==============================] - 11s 123ms/step - loss: 0.4607 - accuracy: 0.8239 - val_loss: 0.7639 - val_accuracy: 0.6989 - lr: 0.0010
# Epoch 31/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4532 - accuracy: 0.8249
# Epoch 31: val_loss did not improve from 0.66852
# 92/92 [==============================] - 11s 123ms/step - loss: 0.4532 - accuracy: 0.8249 - val_loss: 0.7052 - val_accuracy: 0.7480 - lr: 0.0010
# Epoch 32/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4533 - accuracy: 0.8130
# Epoch 32: val_loss did not improve from 0.66852
# 92/92 [==============================] - 11s 121ms/step - loss: 0.4533 - accuracy: 0.8130 - val_loss: 0.7382 - val_accuracy: 0.7357 - lr: 0.0010
# Epoch 33/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4484 - accuracy: 0.8239
# Epoch 33: val_loss improved from 0.66852 to 0.64692, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 19s 205ms/step - loss: 0.4484 - accuracy: 0.8239 - val_loss: 0.6469 - val_accuracy: 0.7643 - lr: 0.0010
# Epoch 34/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4104 - accuracy: 0.8426
# Epoch 34: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 123ms/step - loss: 0.4104 - accuracy: 0.8426 - val_loss: 0.7358 - val_accuracy: 0.7520 - lr: 0.0010
# Epoch 35/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4188 - accuracy: 0.8416
# Epoch 35: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 124ms/step - loss: 0.4188 - accuracy: 0.8416 - val_loss: 0.7113 - val_accuracy: 0.7398 - lr: 0.0010
# Epoch 36/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4077 - accuracy: 0.8382
# Epoch 36: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 124ms/step - loss: 0.4077 - accuracy: 0.8382 - val_loss: 0.7413 - val_accuracy: 0.7357 - lr: 0.0010
# Epoch 37/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4091 - accuracy: 0.8409
# Epoch 37: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 123ms/step - loss: 0.4091 - accuracy: 0.8409 - val_loss: 0.7386 - val_accuracy: 0.7520 - lr: 0.0010
# Epoch 38/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3941 - accuracy: 0.8491
# Epoch 38: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 123ms/step - loss: 0.3941 - accuracy: 0.8491 - val_loss: 0.7553 - val_accuracy: 0.7357 - lr: 0.0010
# Epoch 39/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3831 - accuracy: 0.8491
# Epoch 39: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 123ms/step - loss: 0.3831 - accuracy: 0.8491 - val_loss: 0.9287 - val_accuracy: 0.7439 - lr: 0.0010
# Epoch 40/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3593 - accuracy: 0.8621
# Epoch 40: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 123ms/step - loss: 0.3593 - accuracy: 0.8621 - val_loss: 0.8613 - val_accuracy: 0.7302 - lr: 0.0010
# Epoch 41/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3658 - accuracy: 0.8498
# Epoch 41: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 123ms/step - loss: 0.3658 - accuracy: 0.8498 - val_loss: 0.7991 - val_accuracy: 0.7589 - lr: 0.0010
# Epoch 42/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3326 - accuracy: 0.8743
# Epoch 42: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 123ms/step - loss: 0.3326 - accuracy: 0.8743 - val_loss: 0.7559 - val_accuracy: 0.7466 - lr: 0.0010
# Epoch 43/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3493 - accuracy: 0.8627
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 43: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 122ms/step - loss: 0.3493 - accuracy: 0.8627 - val_loss: 0.8638 - val_accuracy: 0.7411 - lr: 0.0010
# Epoch 44/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2854 - accuracy: 0.8866
# Epoch 44: val_loss did not improve from 0.64692
# 92/92 [==============================] - 12s 128ms/step - loss: 0.2854 - accuracy: 0.8866 - val_loss: 0.6871 - val_accuracy: 0.7847 - lr: 5.0000e-04
# Epoch 45/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2881 - accuracy: 0.8903
# Epoch 45: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 122ms/step - loss: 0.2881 - accuracy: 0.8903 - val_loss: 0.8300 - val_accuracy: 0.7616 - lr: 5.0000e-04
# Epoch 46/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2595 - accuracy: 0.8944
# Epoch 46: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 123ms/step - loss: 0.2595 - accuracy: 0.8944 - val_loss: 0.7665 - val_accuracy: 0.7711 - lr: 5.0000e-04
# Epoch 47/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2475 - accuracy: 0.9050
# Epoch 47: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 123ms/step - loss: 0.2475 - accuracy: 0.9050 - val_loss: 0.7765 - val_accuracy: 0.7888 - lr: 5.0000e-04
# Epoch 48/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2388 - accuracy: 0.9053
# Epoch 48: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 124ms/step - loss: 0.2388 - accuracy: 0.9053 - val_loss: 0.7678 - val_accuracy: 0.7725 - lr: 5.0000e-04
# Epoch 49/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2303 - accuracy: 0.9152
# Epoch 49: val_loss did not improve from 0.64692
# 92/92 [==============================] - 12s 130ms/step - loss: 0.2303 - accuracy: 0.9152 - val_loss: 0.8330 - val_accuracy: 0.7684 - lr: 5.0000e-04
# Epoch 50/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2296 - accuracy: 0.9125
# Epoch 50: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 123ms/step - loss: 0.2296 - accuracy: 0.9125 - val_loss: 0.8125 - val_accuracy: 0.7684 - lr: 5.0000e-04
# Epoch 51/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2396 - accuracy: 0.9067
# Epoch 51: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 122ms/step - loss: 0.2396 - accuracy: 0.9067 - val_loss: 0.8085 - val_accuracy: 0.7834 - lr: 5.0000e-04
# Epoch 52/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9142
# Epoch 52: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 122ms/step - loss: 0.2082 - accuracy: 0.9142 - val_loss: 0.8995 - val_accuracy: 0.7738 - lr: 5.0000e-04
# Epoch 53/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2086 - accuracy: 0.9176Restoring model weights from the end of the best epoch: 33.
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 53: val_loss did not improve from 0.64692
# 92/92 [==============================] - 11s 124ms/step - loss: 0.2086 - accuracy: 0.9176 - val_loss: 0.8246 - val_accuracy: 0.7875 - lr: 5.0000e-04
# Epoch 53: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 190, 190, 3)       0
#
#  random_flip (RandomFlip)    (None, 190, 190, 3)       0
#
#  random_rotation_1 (RandomR  (None, 190, 190, 3)       0
#  otation)
#
#  conv2d (Conv2D)             (None, 188, 188, 64)      1792
#
#  activation (Activation)     (None, 188, 188, 64)      0
#
#  max_pooling2d (MaxPooling2  (None, 94, 94, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 92, 92, 128)       73856
#
#  activation_1 (Activation)   (None, 92, 92, 128)       0
#
#  max_pooling2d_1 (MaxPoolin  (None, 46, 46, 128)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 44, 44, 256)       295168
#
#  activation_2 (Activation)   (None, 44, 44, 256)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 256)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 512)       1180160
#
#  activation_3 (Activation)   (None, 20, 20, 512)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 10, 10, 512)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 1024)        4719616
#
#  activation_4 (Activation)   (None, 8, 8, 1024)        0
#
#  max_pooling2d_4 (MaxPoolin  (None, 4, 4, 1024)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 2, 2, 2048)        18876416
#
#  activation_5 (Activation)   (None, 2, 2, 2048)        0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 2048)              16779264
#
#  activation_6 (Activation)   (None, 2048)              0
#
#  dense_1 (Dense)             (None, 5)                 10245
#
# =================================================================
# Total params: 41936517 (159.98 MB)
# Trainable params: 41936517 (159.98 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
###-----------------------------------
### Function to plot Loss Curve
###-----------------------------------

def fn_plot_tf_hist(hist_df):
    '''
    Args:
      hist_df : pandas Dataframe with four columns
                For 'x' values, we will use index
    '''
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12

    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]

    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(y1.capitalize(),
                           hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y3].to_numpy()[0]), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)

    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(y2.capitalize(),
                           hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y4].to_numpy()[0]), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow


    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')

    plt.tight_layout()

# %%
loss_df = pd.DataFrame(history.history)
fn_plot_tf_hist(loss_df)

# %%
loss_df[loss_df['val_loss'] == loss_df['val_loss'].min()]
# Out:
#        loss  accuracy  val_loss  val_accuracy     lr
# 32  0.44836   0.82391  0.646918      0.764305  0.001
