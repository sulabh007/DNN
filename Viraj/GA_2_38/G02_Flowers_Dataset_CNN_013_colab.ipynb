# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
#
# ## Convolutional Neural Network
# ### Flower Dataset

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from collections.abc import Callable
from typing import Literal
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %matplotlib inline

# %%
gpus = tf.config.list_physical_devices('GPU')

try:
    for g in gpus:
        tf.config.experimental.set_memory_growth(g, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print (len(gpus), 'Phusical GPUs', len(logical_gpus), 'Logical GPUs')
except:
    print ('invalid device')
# Out:
# 1 Phusical GPUs 1 Logical GPUs

# %%
###----------------
### Some parameters
###----------------

inpDir = '/home/dai/Documents/DNN/7.DNN/input'
outDir = '../output'
modelDir = '../models'
subDir = 'flower_photos'
altName = 'cnn_base'

RANDOM_STATE = 24 # REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results


EPOCHS = 150 # number of epochs
ALPHA = 0.001 # learning rate
TEST_SIZE = 0.2
BATCH_SIZE = 32
LR_PATIENCE = 10
FACTOR_LR = 0.5
PATIENCE = 20
IMG_HEIGHT = 258
IMG_WIDTH = 258

# parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

CMAP = 'coolwarm' # plt.cm.Spectral

plt.rcParams.update(params)

# %%
def fn_plot_label(tr_ds , ts_ds):

    plt.figure(figsize=(15,5)) # instantiate the figure

    plt.subplot(1, 2, 1) # first out of 2

    train_labels = tf.concat([lbl for img, lbl in tr_ds], axis= 0).numpy() # get the lables

    unique, _, counts = tf.unique_with_counts(train_labels) # get counts

    plt.bar(range(len(unique)), counts, align='center', color= 'DarkBlue') # barplot the count

    plt.xticks(range(len(unique)), class_names)

    plt.title('Traning Set')

    plt.subplot(1, 2, 2)

    test_labels = tf.concat([lbl for img, lbl in ts_ds], axis= 0).numpy()

    unique, _, counts = tf.unique_with_counts(test_labels)

    plt.bar(range(len(unique)), counts, align='center', color= 'Orange')

    plt.xticks(range(len(unique)), class_names)

    plt.title('Test Set')

# %% [markdown]
# ### Using Flowers Data

# %% [markdown]
# Coverting to Datasets from a directory

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

data_dir = tf.keras.utils.get_file(origin=dataset_url,
                                  fname='flower_photos',
                                  untar=True)

data_dir = pathlib.Path(data_dir)

# %%
data_dir
# Out:
# PosixPath('/root/.keras/datasets/flower_photos')

# %%
os.listdir(data_dir)
# Out:
# ['tulips', 'daisy', 'LICENSE.txt', 'sunflowers', 'roses', 'dandelion']

# %%
#create traning data
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, #path to the data directory
    validation_split = TEST_SIZE, #what ratio of validation data
    subset = 'training', #purpose
    seed = RANDOM_STATE,
    image_size = [IMG_HEIGHT, IMG_WIDTH],
    batch_size = BATCH_SIZE
)

#create test data
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, #path to the data directory
    validation_split = TEST_SIZE, #what ratio of validation data
    subset = 'validation', #purpose
    seed = RANDOM_STATE,
    image_size = [IMG_HEIGHT, IMG_WIDTH],
    batch_size = BATCH_SIZE
)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
# is it picking class names
class_names = train_ds.class_names
class_names
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
plt.figure(figsize=(15,6))

for images, labels in train_ds.take(1): # get me one batch

    for i in range (BATCH_SIZE): #loop over batch

        plt.subplot(int(BATCH_SIZE/8),8, i+1) # access the axis

        plt.grid(False)

        plt.imshow(images[i].numpy().astype('uint8')) # show image convert to numpy and int

        plt.title(class_names[labels[i]])

        plt.axis('off')

    plt.show()

# %%
plt.figure(figsize=(15,6))

for images, labels in test_ds.take(1): # get me one batch

    for i in range (BATCH_SIZE): #loop over batch

        plt.subplot(int(BATCH_SIZE/8),8, i+1) # access the axis

        plt.grid(False)

        plt.imshow(images[i].numpy().astype('uint8')) # show image convert to numpy and int

        plt.title(class_names[labels[i]])

        plt.axis('off')

    plt.show()

# %%
fn_plot_label(train_ds, test_ds)

# %%
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

# %% [markdown]
# ## Random Zoom

# %%
layer = tf.keras.layers.RandomZoom(height_factor=(-0.2, -0.2),
                                   width_factor=(-0.2, -0.2))

plt.figure()

img_num = 3

for images, labels in test_ds.take(1): # get me one batch

    out_images = layer(images)

    plt.subplot(1, 2, 1)
    plt.title('Orignal')
    plt.imshow(images[img_num].numpy().astype('uint8'))

    plt.subplot(1, 2, 2)
    plt.title('Zoomed')
    plt.imshow(out_images[img_num].numpy().astype('uint8'))

# %%
layer = tf.keras.layers.RandomRotation((-0.2, 0.3))

plt.figure()

img_num = 3

for images, labels in test_ds.take(1): # get me one batch

    out_images = layer(images)

    plt.subplot(1, 2, 1)
    plt.title('Orignal')
    plt.imshow(images[img_num].numpy().astype('uint8'))

    plt.subplot(1, 2, 2)
    plt.title('Rotated')
    plt.imshow(out_images[img_num].numpy().astype('uint8'))

# %%
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

test_ds = test_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Build model
dor1 = 0.01
#knl_reg = tf.keras.regularizers.L2(l2 = 0)
model = tf.keras.Sequential()

# model.add(tf.keras.layers.RandomZoom(height_factor=(-0.2, -0.2), width_factor=(-0.2, -0.2)))



model.add(tf.keras.layers.Rescaling(1/255.)), # Convert between 0 and 1
model.add(tf.keras.layers.RandomFlip("horizontal"))
model.add(tf.keras.layers.RandomRotation((-0.2, 0.3)))

###-------
### Set 1
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(32, (3,3))), # 188 x 188 x 8

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 94 x 94 x 8

###-------
### Set 2
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(64, (3,3))), # 92 x 92 x 16

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# Conv layer
model.add(tf.keras.layers.Conv2D(128, (3,3))), # 92 x 92 x 16

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),
# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 46 x 46 x 16

###-------
### Set 3
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(256, (3,3))), # 44 x 44 x 32

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 22 x 22 x 32

###-------
### Set 4
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(512, (3,3))), # 20 x 20 x 64

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 10 x 10 x 64

###-------
### Set 5
###-------
# Conv layer
model.add(tf.keras.layers.Conv2D(1024, (3,3))), # 8 x 8 x 128

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
### Pooling
model.add(tf.keras.layers.MaxPool2D(2, 2)), # 4 x 4 x 128

###-------
### Set 6
###-------

model.add(tf.keras.layers.Conv2D(2048, (3,3))), # 2 x 2 x 256

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))
###------------
### Head Start
###------------
model.add(tf.keras.layers.Flatten()), # Flatten

model.add(tf.keras.layers.Dense(2048)), # Dense 1

# model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Activation('relu')),

# model.add(tf.keras.layers.Dropout(rate=dor1, seed=RANDOM_STATE))

model.add(tf.keras.layers.Dense(5)) #Output

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE,
    mode = 'auto',
    baseline = None,
    verbose=1,
    restore_best_weights=True,
    start_from_epoch=0,
)
lr_decay = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=FACTOR_LR,
    patience=LR_PATIENCE,
    verbose=1,
    mode='auto',

)

#define model file path
modelFile = os.path.join(modelDir, subDir, altName)

#define checkpoint callback
model_callback = tf.keras.callbacks.ModelCheckpoint(
    modelFile,
    monitor = 'val_loss',
    verbose = 1,
    save_best_only = True,
    save_weights_only = True,
    mode = 'auto'
)

# %%
optim = tf.keras.optimizers.AdamW(learning_rate = ALPHA)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

model.compile(optimizer = optim, loss = loss_fn, metrics = ['accuracy'])

# %%
history = model.fit(train_ds, validation_data=test_ds,
                    epochs=EPOCHS, verbose = 1,
                    batch_size=BATCH_SIZE,
                    callbacks=[early_stopping, lr_decay, model_callback])
# Out:
# Epoch 1/150
# 92/92 [==============================] - ETA: 0s - loss: 1.7908 - accuracy: 0.2428
# Epoch 1: val_loss improved from inf to 1.60146, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 52s 403ms/step - loss: 1.7908 - accuracy: 0.2428 - val_loss: 1.6015 - val_accuracy: 0.2384 - lr: 0.0010
# Epoch 2/150
# 92/92 [==============================] - ETA: 0s - loss: 1.4977 - accuracy: 0.3099
# Epoch 2: val_loss improved from 1.60146 to 1.50725, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 36s 397ms/step - loss: 1.4977 - accuracy: 0.3099 - val_loss: 1.5073 - val_accuracy: 0.3706 - lr: 0.0010
# Epoch 3/150
# 92/92 [==============================] - ETA: 0s - loss: 1.1763 - accuracy: 0.5089
# Epoch 3: val_loss improved from 1.50725 to 1.17336, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 26s 283ms/step - loss: 1.1763 - accuracy: 0.5089 - val_loss: 1.1734 - val_accuracy: 0.5095 - lr: 0.0010
# Epoch 4/150
# 92/92 [==============================] - ETA: 0s - loss: 1.0711 - accuracy: 0.5787
# Epoch 4: val_loss improved from 1.17336 to 1.10628, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 26s 280ms/step - loss: 1.0711 - accuracy: 0.5787 - val_loss: 1.1063 - val_accuracy: 0.5545 - lr: 0.0010
# Epoch 5/150
# 92/92 [==============================] - ETA: 0s - loss: 1.0053 - accuracy: 0.5978
# Epoch 5: val_loss improved from 1.10628 to 1.09615, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 25s 276ms/step - loss: 1.0053 - accuracy: 0.5978 - val_loss: 1.0962 - val_accuracy: 0.5736 - lr: 0.0010
# Epoch 6/150
# 92/92 [==============================] - ETA: 0s - loss: 0.9436 - accuracy: 0.6192
# Epoch 6: val_loss improved from 1.09615 to 1.08713, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 25s 276ms/step - loss: 0.9436 - accuracy: 0.6192 - val_loss: 1.0871 - val_accuracy: 0.5300 - lr: 0.0010
# Epoch 7/150
# 92/92 [==============================] - ETA: 0s - loss: 0.8984 - accuracy: 0.6526
# Epoch 7: val_loss improved from 1.08713 to 0.98237, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 44s 483ms/step - loss: 0.8984 - accuracy: 0.6526 - val_loss: 0.9824 - val_accuracy: 0.6444 - lr: 0.0010
# Epoch 8/150
# 92/92 [==============================] - ETA: 0s - loss: 0.8582 - accuracy: 0.6611
# Epoch 8: val_loss improved from 0.98237 to 0.94258, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 42s 455ms/step - loss: 0.8582 - accuracy: 0.6611 - val_loss: 0.9426 - val_accuracy: 0.6594 - lr: 0.0010
# Epoch 9/150
# 92/92 [==============================] - ETA: 0s - loss: 0.8269 - accuracy: 0.6747
# Epoch 9: val_loss did not improve from 0.94258
# 92/92 [==============================] - 20s 216ms/step - loss: 0.8269 - accuracy: 0.6747 - val_loss: 1.0163 - val_accuracy: 0.6253 - lr: 0.0010
# Epoch 10/150
# 92/92 [==============================] - ETA: 0s - loss: 0.8048 - accuracy: 0.6965
# Epoch 10: val_loss improved from 0.94258 to 0.93421, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 40s 437ms/step - loss: 0.8048 - accuracy: 0.6965 - val_loss: 0.9342 - val_accuracy: 0.6635 - lr: 0.0010
# Epoch 11/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7780 - accuracy: 0.7033
# Epoch 11: val_loss did not improve from 0.93421
# 92/92 [==============================] - 20s 216ms/step - loss: 0.7780 - accuracy: 0.7033 - val_loss: 0.9435 - val_accuracy: 0.6485 - lr: 0.0010
# Epoch 12/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7637 - accuracy: 0.7105
# Epoch 12: val_loss improved from 0.93421 to 0.85400, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 40s 434ms/step - loss: 0.7637 - accuracy: 0.7105 - val_loss: 0.8540 - val_accuracy: 0.6853 - lr: 0.0010
# Epoch 13/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7516 - accuracy: 0.7105
# Epoch 13: val_loss improved from 0.85400 to 0.83322, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 44s 483ms/step - loss: 0.7516 - accuracy: 0.7105 - val_loss: 0.8332 - val_accuracy: 0.6798 - lr: 0.0010
# Epoch 14/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7265 - accuracy: 0.7095
# Epoch 14: val_loss did not improve from 0.83322
# 92/92 [==============================] - 20s 216ms/step - loss: 0.7265 - accuracy: 0.7095 - val_loss: 0.9082 - val_accuracy: 0.6730 - lr: 0.0010
# Epoch 15/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7434 - accuracy: 0.7030
# Epoch 15: val_loss improved from 0.83322 to 0.81153, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 44s 484ms/step - loss: 0.7434 - accuracy: 0.7030 - val_loss: 0.8115 - val_accuracy: 0.7003 - lr: 0.0010
# Epoch 16/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7380 - accuracy: 0.7139
# Epoch 16: val_loss did not improve from 0.81153
# 92/92 [==============================] - 20s 215ms/step - loss: 0.7380 - accuracy: 0.7139 - val_loss: 0.8395 - val_accuracy: 0.6798 - lr: 0.0010
# Epoch 17/150
# 92/92 [==============================] - ETA: 0s - loss: 0.7094 - accuracy: 0.7217
# Epoch 17: val_loss did not improve from 0.81153
# 92/92 [==============================] - 20s 217ms/step - loss: 0.7094 - accuracy: 0.7217 - val_loss: 0.8933 - val_accuracy: 0.6676 - lr: 0.0010
# Epoch 18/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6616 - accuracy: 0.7463
# Epoch 18: val_loss improved from 0.81153 to 0.79450, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 40s 432ms/step - loss: 0.6616 - accuracy: 0.7463 - val_loss: 0.7945 - val_accuracy: 0.6935 - lr: 0.0010
# Epoch 19/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6832 - accuracy: 0.7388
# Epoch 19: val_loss improved from 0.79450 to 0.78264, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 35s 377ms/step - loss: 0.6832 - accuracy: 0.7388 - val_loss: 0.7826 - val_accuracy: 0.7044 - lr: 0.0010
# Epoch 20/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6493 - accuracy: 0.7510
# Epoch 20: val_loss did not improve from 0.78264
# 92/92 [==============================] - 21s 231ms/step - loss: 0.6493 - accuracy: 0.7510 - val_loss: 0.8386 - val_accuracy: 0.6866 - lr: 0.0010
# Epoch 21/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6450 - accuracy: 0.7435
# Epoch 21: val_loss improved from 0.78264 to 0.76362, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 35s 377ms/step - loss: 0.6450 - accuracy: 0.7435 - val_loss: 0.7636 - val_accuracy: 0.7098 - lr: 0.0010
# Epoch 22/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6472 - accuracy: 0.7463
# Epoch 22: val_loss did not improve from 0.76362
# 92/92 [==============================] - 20s 215ms/step - loss: 0.6472 - accuracy: 0.7463 - val_loss: 0.8077 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 23/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6285 - accuracy: 0.7568
# Epoch 23: val_loss did not improve from 0.76362
# 92/92 [==============================] - 20s 216ms/step - loss: 0.6285 - accuracy: 0.7568 - val_loss: 0.7736 - val_accuracy: 0.6962 - lr: 0.0010
# Epoch 24/150
# 92/92 [==============================] - ETA: 0s - loss: 0.6127 - accuracy: 0.7561
# Epoch 24: val_loss did not improve from 0.76362
# 92/92 [==============================] - 20s 217ms/step - loss: 0.6127 - accuracy: 0.7561 - val_loss: 0.7792 - val_accuracy: 0.6948 - lr: 0.0010
# Epoch 25/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5972 - accuracy: 0.7609
# Epoch 25: val_loss did not improve from 0.76362
# 92/92 [==============================] - 20s 216ms/step - loss: 0.5972 - accuracy: 0.7609 - val_loss: 0.7643 - val_accuracy: 0.7234 - lr: 0.0010
# Epoch 26/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5999 - accuracy: 0.7674
# Epoch 26: val_loss did not improve from 0.76362
# 92/92 [==============================] - 20s 216ms/step - loss: 0.5999 - accuracy: 0.7674 - val_loss: 0.7719 - val_accuracy: 0.7016 - lr: 0.0010
# Epoch 27/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5791 - accuracy: 0.7657
# Epoch 27: val_loss did not improve from 0.76362
# 92/92 [==============================] - 20s 217ms/step - loss: 0.5791 - accuracy: 0.7657 - val_loss: 0.8223 - val_accuracy: 0.7044 - lr: 0.0010
# Epoch 28/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5567 - accuracy: 0.7841
# Epoch 28: val_loss improved from 0.76362 to 0.75083, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 36s 390ms/step - loss: 0.5567 - accuracy: 0.7841 - val_loss: 0.7508 - val_accuracy: 0.7330 - lr: 0.0010
# Epoch 29/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5421 - accuracy: 0.7864
# Epoch 29: val_loss improved from 0.75083 to 0.74925, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 49s 535ms/step - loss: 0.5421 - accuracy: 0.7864 - val_loss: 0.7492 - val_accuracy: 0.7316 - lr: 0.0010
# Epoch 30/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5484 - accuracy: 0.7755
# Epoch 30: val_loss did not improve from 0.74925
# 92/92 [==============================] - 20s 217ms/step - loss: 0.5484 - accuracy: 0.7755 - val_loss: 0.7642 - val_accuracy: 0.7248 - lr: 0.0010
# Epoch 31/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5720 - accuracy: 0.7725
# Epoch 31: val_loss did not improve from 0.74925
# 92/92 [==============================] - 20s 217ms/step - loss: 0.5720 - accuracy: 0.7725 - val_loss: 0.8033 - val_accuracy: 0.7289 - lr: 0.0010
# Epoch 32/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5283 - accuracy: 0.7895
# Epoch 32: val_loss improved from 0.74925 to 0.70730, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 38s 414ms/step - loss: 0.5283 - accuracy: 0.7895 - val_loss: 0.7073 - val_accuracy: 0.7330 - lr: 0.0010
# Epoch 33/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5272 - accuracy: 0.7881
# Epoch 33: val_loss did not improve from 0.70730
# 92/92 [==============================] - 20s 215ms/step - loss: 0.5272 - accuracy: 0.7881 - val_loss: 0.7142 - val_accuracy: 0.7398 - lr: 0.0010
# Epoch 34/150
# 92/92 [==============================] - ETA: 0s - loss: 0.5195 - accuracy: 0.7939
# Epoch 34: val_loss did not improve from 0.70730
# 92/92 [==============================] - 20s 218ms/step - loss: 0.5195 - accuracy: 0.7939 - val_loss: 0.7402 - val_accuracy: 0.7221 - lr: 0.0010
# Epoch 35/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4822 - accuracy: 0.8110
# Epoch 35: val_loss improved from 0.70730 to 0.68768, saving model to ../models/flower_photos/cnn_base
# 92/92 [==============================] - 46s 498ms/step - loss: 0.4822 - accuracy: 0.8110 - val_loss: 0.6877 - val_accuracy: 0.7425 - lr: 0.0010
# Epoch 36/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4926 - accuracy: 0.8035
# Epoch 36: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 214ms/step - loss: 0.4926 - accuracy: 0.8035 - val_loss: 0.8001 - val_accuracy: 0.7016 - lr: 0.0010
# Epoch 37/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4675 - accuracy: 0.8130
# Epoch 37: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 217ms/step - loss: 0.4675 - accuracy: 0.8130 - val_loss: 0.7251 - val_accuracy: 0.7439 - lr: 0.0010
# Epoch 38/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4719 - accuracy: 0.8079
# Epoch 38: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 217ms/step - loss: 0.4719 - accuracy: 0.8079 - val_loss: 0.7407 - val_accuracy: 0.7357 - lr: 0.0010
# Epoch 39/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4578 - accuracy: 0.8188
# Epoch 39: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 216ms/step - loss: 0.4578 - accuracy: 0.8188 - val_loss: 0.6948 - val_accuracy: 0.7316 - lr: 0.0010
# Epoch 40/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4584 - accuracy: 0.8144
# Epoch 40: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 216ms/step - loss: 0.4584 - accuracy: 0.8144 - val_loss: 0.7158 - val_accuracy: 0.7371 - lr: 0.0010
# Epoch 41/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4311 - accuracy: 0.8246
# Epoch 41: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 216ms/step - loss: 0.4311 - accuracy: 0.8246 - val_loss: 0.9059 - val_accuracy: 0.7071 - lr: 0.0010
# Epoch 42/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4586 - accuracy: 0.8151
# Epoch 42: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 217ms/step - loss: 0.4586 - accuracy: 0.8151 - val_loss: 0.7167 - val_accuracy: 0.7643 - lr: 0.0010
# Epoch 43/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4259 - accuracy: 0.8324
# Epoch 43: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 217ms/step - loss: 0.4259 - accuracy: 0.8324 - val_loss: 0.8151 - val_accuracy: 0.7289 - lr: 0.0010
# Epoch 44/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4407 - accuracy: 0.8253
# Epoch 44: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 216ms/step - loss: 0.4407 - accuracy: 0.8253 - val_loss: 0.7545 - val_accuracy: 0.7302 - lr: 0.0010
# Epoch 45/150
# 92/92 [==============================] - ETA: 0s - loss: 0.4275 - accuracy: 0.8324
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 45: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 217ms/step - loss: 0.4275 - accuracy: 0.8324 - val_loss: 0.8030 - val_accuracy: 0.7262 - lr: 0.0010
# Epoch 46/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3601 - accuracy: 0.8617
# Epoch 46: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 216ms/step - loss: 0.3601 - accuracy: 0.8617 - val_loss: 0.7662 - val_accuracy: 0.7534 - lr: 5.0000e-04
# Epoch 47/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3328 - accuracy: 0.8713
# Epoch 47: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 217ms/step - loss: 0.3328 - accuracy: 0.8713 - val_loss: 0.7856 - val_accuracy: 0.7439 - lr: 5.0000e-04
# Epoch 48/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3117 - accuracy: 0.8747
# Epoch 48: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 216ms/step - loss: 0.3117 - accuracy: 0.8747 - val_loss: 0.8450 - val_accuracy: 0.7520 - lr: 5.0000e-04
# Epoch 49/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3050 - accuracy: 0.8750
# Epoch 49: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 217ms/step - loss: 0.3050 - accuracy: 0.8750 - val_loss: 0.7499 - val_accuracy: 0.7698 - lr: 5.0000e-04
# Epoch 50/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3266 - accuracy: 0.8726
# Epoch 50: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 217ms/step - loss: 0.3266 - accuracy: 0.8726 - val_loss: 0.8051 - val_accuracy: 0.7589 - lr: 5.0000e-04
# Epoch 51/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2936 - accuracy: 0.8787
# Epoch 51: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 216ms/step - loss: 0.2936 - accuracy: 0.8787 - val_loss: 0.8035 - val_accuracy: 0.7561 - lr: 5.0000e-04
# Epoch 52/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2685 - accuracy: 0.8910
# Epoch 52: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 217ms/step - loss: 0.2685 - accuracy: 0.8910 - val_loss: 0.8777 - val_accuracy: 0.7738 - lr: 5.0000e-04
# Epoch 53/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2702 - accuracy: 0.8907
# Epoch 53: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 217ms/step - loss: 0.2702 - accuracy: 0.8907 - val_loss: 0.8703 - val_accuracy: 0.7711 - lr: 5.0000e-04
# Epoch 54/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2607 - accuracy: 0.8988
# Epoch 54: val_loss did not improve from 0.68768
# 92/92 [==============================] - 20s 217ms/step - loss: 0.2607 - accuracy: 0.8988 - val_loss: 1.0051 - val_accuracy: 0.7589 - lr: 5.0000e-04
# Epoch 55/150
# 92/92 [==============================] - ETA: 0s - loss: 0.2532 - accuracy: 0.8948Restoring model weights from the end of the best epoch: 35.
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 55: val_loss did not improve from 0.68768
# 92/92 [==============================] - 21s 223ms/step - loss: 0.2532 - accuracy: 0.8948 - val_loss: 1.0145 - val_accuracy: 0.7711 - lr: 5.0000e-04
# Epoch 55: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 258, 258, 3)       0
#
#  random_flip (RandomFlip)    (None, 258, 258, 3)       0
#
#  random_rotation_1 (RandomR  (None, 258, 258, 3)       0
#  otation)
#
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  activation (Activation)     (None, 256, 256, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 126, 126, 64)      18496
#
#  activation_1 (Activation)   (None, 126, 126, 64)      0
#
#  conv2d_2 (Conv2D)           (None, 124, 124, 128)     73856
#
#  activation_2 (Activation)   (None, 124, 124, 128)     0
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 60, 60, 256)       295168
#
#  activation_3 (Activation)   (None, 60, 60, 256)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 256)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  activation_4 (Activation)   (None, 28, 28, 512)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 512)       0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 1024)      4719616
#
#  activation_5 (Activation)   (None, 12, 12, 1024)      0
#
#  max_pooling2d_4 (MaxPoolin  (None, 6, 6, 1024)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 2048)        18876416
#
#  activation_6 (Activation)   (None, 4, 4, 2048)        0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 2048)              67110912
#
#  activation_7 (Activation)   (None, 2048)              0
#
#  dense_1 (Dense)             (None, 5)                 10245
#
# =================================================================
# Total params: 92285765 (352.04 MB)
# Trainable params: 92285765 (352.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
###-----------------------------------
### Function to plot Loss Curve
###-----------------------------------

def fn_plot_tf_hist(hist_df):
    '''
    Args:
      hist_df : pandas Dataframe with four columns
                For 'x' values, we will use index
    '''
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12

    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]

    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(y1.capitalize(),
                           hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y3].to_numpy()[0]), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)

    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(y2.capitalize(),
                           hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y4].to_numpy()[0]), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow


    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')

    plt.tight_layout()

# %%
loss_df = pd.DataFrame(history.history)
fn_plot_tf_hist(loss_df)

# %%
loss_df[loss_df['val_loss'] == loss_df['val_loss'].min()]
# Out:
#         loss  accuracy  val_loss  val_accuracy     lr
# 34  0.482204  0.810967  0.687678      0.742507  0.001
