# %%
# Python built-in module
import warnings

# Third-party modules
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras import Input, Sequential
from tensorflow.keras.layers import BatchNormalization, Dense, Dropout, LeakyReLU
import matplotlib.pyplot as plt
import seaborn as sns
from dataclasses import dataclass
from pathlib import Path

from typing import Tuple

# Set random seed and enable operation determinism
tf.keras.utils.set_random_seed(42)
tf.config.experimental.enable_op_determinism()

# Ignore warnings
warnings.filterwarnings("ignore")
# Out:
# 2023-11-29 13:20:36.779042: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-29 13:20:36.841359: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-29 13:20:36.841403: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-29 13:20:36.842786: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-29 13:20:36.852389: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-29 13:20:37.804163: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def prepare_data(df: pd.DataFrame) -> Tuple[np.ndarray, np.ndarray, StandardScaler]:
    # Drop the first column from the dataframe
    df.drop(1, axis=1, inplace=True)
    
    # Initialize a label encoder
    encoder = LabelEncoder()
    
    # Fit and transform the 34th column with the label encoder
    df[34] = encoder.fit_transform(df[34])
    
    # Separate the features (X) and the target variable (y)
    X = df.drop(34, axis=1)
    y = df[34]
    
    # Initialize a standard scaler
    scaler = StandardScaler()
    
    # Fit and transform the features with the standard scaler
    X = scaler.fit_transform(X)
    
    # Return the scaled features, the target variable, and the scaler
    return X, y, scaler

# %%
# Load the dataset
df = pd.read_csv('data/ionosphere.data', header=None)
# Prepare the dataset
X,y, scaler = prepare_data(df)
print(X.shape, y.shape)
# Out:
# (351, 33) (351,)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y, random_state=42, shuffle=True)

# %%
@dataclass
class Params:
    input_dim: int = X.shape[1]  # Input dimension based on features
    output_dim: int = 1  # Output dimension (binary classification)
    dropout: float = 0.3  # Dropout rate for regularization
    learning_rate: float = 0.001  # Learning rate for optimizer
    epochs: int = 150  # Number of training epochs
    batch_size: int = 32  # Batch size for training
    save_dir: str = Path('checkpoints')  # Directory to save model checkpoints
    save_path: str = save_dir/'model.h5'  # Path to save the model
    verbose: int = 1  # Verbosity mode

    # Create directory if it doesn't exist
    save_dir.mkdir(parents=True, exist_ok=True)

# Create an instance of Params
params = Params()

# %%
def create_model(input_size, hidden_size, num_classes, dropout_rate=0.3):
    # Initialize a Sequential model
    model = Sequential([
        # First hidden layer with 'hidden_size*2' neurons, and input dimensionality as 'input_size'
        Dense(hidden_size*2, input_dim=input_size,),
        # Apply LeakyReLU activation function
        LeakyReLU(),
        # Normalize the activations of the previous layer at each batch
        BatchNormalization(),
        
        # Second hidden layer with 'hidden_size*2' neurons
        Dense(hidden_size*2),
        # Apply LeakyReLU activation function
        LeakyReLU(),
        # Normalize the activations of the previous layer at each batch
        BatchNormalization(),
        
        # Third hidden layer with 'hidden_size' neurons
        Dense(hidden_size),
        # Apply LeakyReLU activation function
        LeakyReLU(),
        # Normalize the activations of the previous layer at each batch
        BatchNormalization(),

        
        # Apply dropout with rate 'dropout_rate' to prevent overfitting
        Dropout(dropout_rate),
        
        # Output layer with 'num_classes' neurons and linear activation function
        Dense(num_classes, activation='linear')
    ])
    
    # Return the constructed model
    return model

# %%
model = create_model(input_size = params.input_dim,hidden_size=20,num_classes=params.output_dim, dropout_rate=params.dropout)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 40)                1360
#
#  leaky_re_lu (LeakyReLU)     (None, 40)                0
#
#  batch_normalization (Batch  (None, 40)                160
#  Normalization)
#
#  dense_1 (Dense)             (None, 40)                1640
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 40)                0
#
#  batch_normalization_1 (Bat  (None, 40)                160
#  chNormalization)
#
#  dense_2 (Dense)             (None, 20)                820
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 20)                0
#
#  batch_normalization_2 (Bat  (None, 20)                80
#  chNormalization)
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 4241 (16.57 KB)
# Trainable params: 4041 (15.79 KB)
# Non-trainable params: 200 (800.00 Byte)
# _________________________________________________________________

# %%
# Binary Crossentropy loss function
loss = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# Adam optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=params.learning_rate)

# Learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=params.learning_rate,
    decay_steps=10000,
    decay_rate=0.96,
    staircase=True)

# Assign schedule to optimizer
optimizer.learning_rate = lr_schedule

# Metrics for training monitoring
metrics = ['accuracy', tf.keras.metrics.AUC()]

# Callback to save best model
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    str(params.save_path),
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=params.verbose,)

# Callback for early stopping
early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    mode='min',
    verbose=params.verbose,)

# Callback to reduce learning rate on plateau
reduce_lr_cb = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    patience=5,
    verbose=params.verbose,)

# List of callbacks
callbacks = [early_stopping_cb, reduce_lr_cb, checkpoint_cb]

# Compile the model
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Fit the model
hist = model.fit(X_train, y_train, callbacks=callbacks, validation_data=(X_test, y_test), epochs=params.epochs, batch_size=params.batch_size)
# Out:
# Epoch 1/150
# 2/9 [=====>........................] - ETA: 2s - loss: 0.7807 - accuracy: 0.4844 - auc: 0.6060
# Epoch 1: val_loss improved from inf to 0.62448, saving model to checkpoints/model.h5
# 9/9 [==============================] - 4s 114ms/step - loss: 0.7882 - accuracy: 0.4829 - auc: 0.5654 - val_loss: 0.6245 - val_accuracy: 0.4773 - val_auc: 0.7185 - lr: 0.0010
# Epoch 2/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.7069 - accuracy: 0.5938 - auc: 0.6938
# Epoch 2: val_loss improved from 0.62448 to 0.57306, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 23ms/step - loss: 0.5927 - accuracy: 0.6388 - auc: 0.7369 - val_loss: 0.5731 - val_accuracy: 0.5114 - val_auc: 0.8131 - lr: 0.0010
# Epoch 3/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.5002 - accuracy: 0.6250 - auc: 0.7455
# Epoch 3: val_loss improved from 0.57306 to 0.52158, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4935 - accuracy: 0.7224 - auc: 0.8110 - val_loss: 0.5216 - val_accuracy: 0.6591 - val_auc: 0.8945 - lr: 0.0010
# Epoch 4/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.4909 - accuracy: 0.6875 - auc: 0.7917
# Epoch 4: val_loss improved from 0.52158 to 0.48412, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4272 - accuracy: 0.7795 - auc: 0.8442 - val_loss: 0.4841 - val_accuracy: 0.7273 - val_auc: 0.9280 - lr: 0.0010
# Epoch 5/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.3424 - accuracy: 0.8125 - auc: 0.9353
# Epoch 5: val_loss improved from 0.48412 to 0.45041, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 27ms/step - loss: 0.3926 - accuracy: 0.8099 - auc: 0.8800 - val_loss: 0.4504 - val_accuracy: 0.7500 - val_auc: 0.9531 - lr: 0.0010
# Epoch 6/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.3378 - accuracy: 0.8438 - auc: 0.8853
# Epoch 6: val_loss improved from 0.45041 to 0.42248, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 23ms/step - loss: 0.3323 - accuracy: 0.8517 - auc: 0.9152 - val_loss: 0.4225 - val_accuracy: 0.7841 - val_auc: 0.9595 - lr: 0.0010
# Epoch 7/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.3382 - accuracy: 0.7812 - auc: 0.8874
# Epoch 7: val_loss improved from 0.42248 to 0.39849, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 25ms/step - loss: 0.3031 - accuracy: 0.8631 - auc: 0.9066 - val_loss: 0.3985 - val_accuracy: 0.8295 - val_auc: 0.9498 - lr: 0.0010
# Epoch 8/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2525 - accuracy: 0.9375 - auc: 0.9625
# Epoch 8: val_loss improved from 0.39849 to 0.36347, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 26ms/step - loss: 0.2936 - accuracy: 0.8783 - auc: 0.9328 - val_loss: 0.3635 - val_accuracy: 0.8636 - val_auc: 0.9612 - lr: 0.0010
# Epoch 9/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1240 - accuracy: 1.0000 - auc: 1.0000
# Epoch 9: val_loss improved from 0.36347 to 0.33024, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 27ms/step - loss: 0.2599 - accuracy: 0.8935 - auc: 0.9325 - val_loss: 0.3302 - val_accuracy: 0.8864 - val_auc: 0.9506 - lr: 0.0010
# Epoch 10/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1833 - accuracy: 0.9688 - auc: 1.0000
# Epoch 10: val_loss improved from 0.33024 to 0.31080, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 26ms/step - loss: 0.2433 - accuracy: 0.9087 - auc: 0.9484 - val_loss: 0.3108 - val_accuracy: 0.8864 - val_auc: 0.9227 - lr: 0.0010
# Epoch 11/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1316 - accuracy: 0.9688 - auc: 1.0000
# Epoch 11: val_loss improved from 0.31080 to 0.30491, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 23ms/step - loss: 0.2454 - accuracy: 0.9163 - auc: 0.9312 - val_loss: 0.3049 - val_accuracy: 0.8977 - val_auc: 0.9358 - lr: 0.0010
# Epoch 12/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2621 - accuracy: 0.9062 - auc: 0.9583
# Epoch 12: val_loss improved from 0.30491 to 0.29846, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 26ms/step - loss: 0.2267 - accuracy: 0.9202 - auc: 0.9367 - val_loss: 0.2985 - val_accuracy: 0.8977 - val_auc: 0.9375 - lr: 0.0010
# Epoch 13/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2631 - accuracy: 0.8750 - auc: 0.9469
# Epoch 13: val_loss improved from 0.29846 to 0.27584, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2368 - accuracy: 0.9125 - auc: 0.9379 - val_loss: 0.2758 - val_accuracy: 0.9205 - val_auc: 0.9386 - lr: 0.0010
# Epoch 14/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1891 - accuracy: 0.9688 - auc: 0.9623
# Epoch 14: val_loss improved from 0.27584 to 0.25608, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2051 - accuracy: 0.9316 - auc: 0.9629 - val_loss: 0.2561 - val_accuracy: 0.9205 - val_auc: 0.9263 - lr: 0.0010
# Epoch 15/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1295 - accuracy: 0.9688 - auc: 1.0000
# Epoch 15: val_loss did not improve from 0.25608
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1866 - accuracy: 0.9202 - auc: 0.9618 - val_loss: 0.2745 - val_accuracy: 0.8977 - val_auc: 0.9308 - lr: 0.0010
# Epoch 16/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2108 - accuracy: 0.9375 - auc: 0.9500
# Epoch 16: val_loss improved from 0.25608 to 0.25492, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 25ms/step - loss: 0.1882 - accuracy: 0.9316 - auc: 0.9570 - val_loss: 0.2549 - val_accuracy: 0.8977 - val_auc: 0.9263 - lr: 0.0010
# Epoch 17/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2300 - accuracy: 0.8750 - auc: 0.9469
# Epoch 17: val_loss improved from 0.25492 to 0.24152, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 23ms/step - loss: 0.1841 - accuracy: 0.9316 - auc: 0.9535 - val_loss: 0.2415 - val_accuracy: 0.9205 - val_auc: 0.9300 - lr: 0.0010
# Epoch 18/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1719 - accuracy: 0.9688 - auc: 0.9562
# Epoch 18: val_loss improved from 0.24152 to 0.22365, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 22ms/step - loss: 0.1781 - accuracy: 0.9392 - auc: 0.9570 - val_loss: 0.2237 - val_accuracy: 0.9318 - val_auc: 0.9487 - lr: 0.0010
# Epoch 19/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1656 - accuracy: 0.9688 - auc: 0.9783
# Epoch 19: val_loss improved from 0.22365 to 0.21692, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 25ms/step - loss: 0.1682 - accuracy: 0.9506 - auc: 0.9627 - val_loss: 0.2169 - val_accuracy: 0.9432 - val_auc: 0.9487 - lr: 0.0010
# Epoch 20/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1626 - accuracy: 0.9688 - auc: 0.9702
# Epoch 20: val_loss improved from 0.21692 to 0.20924, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 21ms/step - loss: 0.1439 - accuracy: 0.9582 - auc: 0.9756 - val_loss: 0.2092 - val_accuracy: 0.9432 - val_auc: 0.9495 - lr: 0.0010
# Epoch 21/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1216 - accuracy: 0.9375 - auc: 0.9783
# Epoch 21: val_loss improved from 0.20924 to 0.20367, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 22ms/step - loss: 0.1385 - accuracy: 0.9658 - auc: 0.9819 - val_loss: 0.2037 - val_accuracy: 0.9432 - val_auc: 0.9489 - lr: 0.0010
# Epoch 22/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1491 - accuracy: 0.9375 - auc: 0.9773
# Epoch 22: val_loss did not improve from 0.20367
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1380 - accuracy: 0.9468 - auc: 0.9770 - val_loss: 0.2040 - val_accuracy: 0.9432 - val_auc: 0.9347 - lr: 0.0010
# Epoch 23/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1116 - accuracy: 1.0000 - auc: 1.0000
# Epoch 23: val_loss improved from 0.20367 to 0.19509, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 26ms/step - loss: 0.1747 - accuracy: 0.9506 - auc: 0.9604 - val_loss: 0.1951 - val_accuracy: 0.9432 - val_auc: 0.9364 - lr: 0.0010
# Epoch 24/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1187 - accuracy: 0.9688 - auc: 1.0000
# Epoch 24: val_loss improved from 0.19509 to 0.19221, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1174 - accuracy: 0.9620 - auc: 0.9787 - val_loss: 0.1922 - val_accuracy: 0.9545 - val_auc: 0.9364 - lr: 0.0010
# Epoch 25/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1046 - accuracy: 0.9688 - auc: 1.0000
# Epoch 25: val_loss did not improve from 0.19221
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1386 - accuracy: 0.9354 - auc: 0.9617 - val_loss: 0.1941 - val_accuracy: 0.9545 - val_auc: 0.9364 - lr: 0.0010
# Epoch 26/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1948 - accuracy: 0.9375 - auc: 0.9524
# Epoch 26: val_loss did not improve from 0.19221
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1215 - accuracy: 0.9544 - auc: 0.9794 - val_loss: 0.1935 - val_accuracy: 0.9545 - val_auc: 0.9342 - lr: 0.0010
# Epoch 27/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0754 - accuracy: 0.9688 - auc: 1.0000
# Epoch 27: val_loss improved from 0.19221 to 0.18938, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 22ms/step - loss: 0.1273 - accuracy: 0.9392 - auc: 0.9718 - val_loss: 0.1894 - val_accuracy: 0.9545 - val_auc: 0.9364 - lr: 0.0010
# Epoch 28/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1066 - accuracy: 0.9375 - auc: 0.9773
# Epoch 28: val_loss did not improve from 0.18938
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1238 - accuracy: 0.9658 - auc: 0.9742 - val_loss: 0.1942 - val_accuracy: 0.9545 - val_auc: 0.9364 - lr: 0.0010
# Epoch 29/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1012 - accuracy: 1.0000 - auc: 1.0000
# Epoch 29: val_loss did not improve from 0.18938
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1334 - accuracy: 0.9544 - auc: 0.9647 - val_loss: 0.2018 - val_accuracy: 0.9545 - val_auc: 0.9353 - lr: 0.0010
# Epoch 30/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1420 - accuracy: 0.9375 - auc: 0.9575
# Epoch 30: val_loss did not improve from 0.18938
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1153 - accuracy: 0.9658 - auc: 0.9714 - val_loss: 0.2019 - val_accuracy: 0.9432 - val_auc: 0.9353 - lr: 0.0010
# Epoch 31/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1595 - accuracy: 0.9375 - auc: 0.9722
# Epoch 31: val_loss did not improve from 0.18938
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1108 - accuracy: 0.9544 - auc: 0.9672 - val_loss: 0.1980 - val_accuracy: 0.9432 - val_auc: 0.9353 - lr: 0.0010
# Epoch 32/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0583 - accuracy: 1.0000 - auc: 1.0000
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 32: val_loss did not improve from 0.18938
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1206 - accuracy: 0.9658 - auc: 0.9760 - val_loss: 0.1961 - val_accuracy: 0.9545 - val_auc: 0.9364 - lr: 0.0010
# Epoch 33/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1313 - accuracy: 0.9688 - auc: 0.9717
# Epoch 33: val_loss did not improve from 0.18938
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1002 - accuracy: 0.9620 - auc: 0.9808 - val_loss: 0.2031 - val_accuracy: 0.9545 - val_auc: 0.9364 - lr: 0.0010
# Epoch 34/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0621 - accuracy: 1.0000 - auc: 1.0000
# Epoch 34: val_loss did not improve from 0.18938
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1131 - accuracy: 0.9544 - auc: 0.9673 - val_loss: 0.2002 - val_accuracy: 0.9545 - val_auc: 0.9364 - lr: 0.0010
# Epoch 35/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2567 - accuracy: 0.8750 - auc: 0.9200
# Epoch 35: val_loss did not improve from 0.18938
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1271 - accuracy: 0.9620 - auc: 0.9572 - val_loss: 0.2187 - val_accuracy: 0.9545 - val_auc: 0.9364 - lr: 0.0010
# Epoch 36/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1072 - accuracy: 0.9688 - auc: 0.9595
# Epoch 36: val_loss did not improve from 0.18938
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0794 - accuracy: 0.9734 - auc: 0.9860 - val_loss: 0.2286 - val_accuracy: 0.9318 - val_auc: 0.9358 - lr: 0.0010
# Epoch 37/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1250 - accuracy: 0.9696 - auc: 0.9708Restoring model weights from the end of the best epoch: 27.
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 37: val_loss did not improve from 0.18938
# 9/9 [==============================] - 0s 20ms/step - loss: 0.1250 - accuracy: 0.9696 - auc: 0.9708 - val_loss: 0.2311 - val_accuracy: 0.9318 - val_auc: 0.9272 - lr: 0.0010
# Epoch 37: early stopping

# %%
# Print the minimum loss values achieved during training and validation
print(f"Minimum training loss: {min(hist.history['loss'])}")
print(f"Minimum validation loss: {min(hist.history['val_loss'])}")

# Set the style of the plots
sns.set_style('darkgrid')

# Plot the training and validation loss over epochs
plt.plot(hist.history['loss'], label='Train')  # Training loss
plt.plot(hist.history['val_loss'], label='Eval')  # Validation loss

# Set the title and labels of the plot
plt.title('Loss Over Epochs')  # Title
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Loss')  # Y-axis label

# Show the legend and the plot
plt.legend()
plt.show()
# Out:
# Minimum training loss: 0.07935279607772827
# Minimum validation loss: 0.189377561211586

# %%
# Print the maximum accuracy values achieved during training and validation
print(f"Maximum training accuracy: {max(hist.history['accuracy'])}")
print(f"Maximum validation accuracy: {max(hist.history['val_accuracy'])}")

# Set the style of the plots
sns.set_style('darkgrid')

# Plot the training and validation accuracy over epochs
plt.plot(hist.history['accuracy'], label='Train')  # Training accuracy
plt.plot(hist.history['val_accuracy'], label='Eval')  # Validation accuracy

# Set the title and labels of the plot
plt.title('Accuracy Over Epochs')  # Title
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Accuracy')  # Y-axis label

# Show the legend and the plot
plt.legend()
plt.show()
# Out:
# Maximum training accuracy: 0.9733840227127075
# Maximum validation accuracy: 0.9545454382896423

# %%
# Print the maximum AUC values achieved during training and validation
print(f"Maximum training AUC: {max(hist.history['auc'])}")
print(f"Maximum validation AUC: {max(hist.history['val_auc'])}")

# Set the style of the plots
sns.set_style('darkgrid')

# Plot the training and validation AUC over epochs
plt.plot(hist.history['auc'], label='Train')  # Training AUC
plt.plot(hist.history['val_auc'], label='Eval')  # Validation AUC

# Set the title and labels of the plot
plt.title('AUC Over Epochs')  # Title
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('AUC')  # Y-axis label

# Show the legend and the plot
plt.legend()
plt.show()
# Out:
# Maximum training AUC: 0.9859625101089478
# Maximum validation AUC: 0.9612165689468384

# %%
#make dataframe of metrics
metrics_df = pd.DataFrame.from_dict(hist.history)
#save metrics to csv
metrics_df.to_csv('metrics.csv', index=False)
